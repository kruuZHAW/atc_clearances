# %%
import re
import pandas as pd

# %% [markdown]
# # 1. Matching flight plan callsigns with adsb data

# %%
flight_plan = pd.read_csv("data/extract_edyy.csv")

# Last message recieved by the NM
flight_plan["timestamp"] = flight_plan["timestamp"].str.replace(
    r" (\d{3})$", r".\1", regex=True
)
flight_plan["timestamp"] = pd.to_datetime(flight_plan["timestamp"])

# Estimated departure time
flight_plan["flightData.flightId.keys.estimatedOffBlockTime"] = flight_plan["flightData.flightId.keys.estimatedOffBlockTime"].str.replace(
    r" (\d{3})$", r".\1", regex=True
)
flight_plan["flightData.flightId.keys.estimatedOffBlockTime"] = pd.to_datetime(flight_plan["flightData.flightId.keys.estimatedOffBlockTime"])

# Estimated arrival time
flight_plan["flightData.estimatedTimeOfArrival"] = flight_plan["flightData.estimatedTimeOfArrival"].str.replace(
    r" (\d{3})$", r".\1", regex=True
)
flight_plan["flightData.estimatedTimeOfArrival"] = pd.to_datetime(flight_plan["flightData.estimatedTimeOfArrival"])

flight_plan.columns
# Out:
# Index(['timestamp', 'flightData.flightId.keys.aircraftId',
#        'flightData.flightId.keys.aerodromeOfDestination',
#        'flightData.flightId.keys.estimatedOffBlockTime',
#        'flightData.flightId.keys.aerodromeOfDeparture',
#        'flightData.flightId.id', 'flightData.estimatedTimeOfArrival',
#        'flightData.aircraftAddress', 'flightData.icaoRoute'],
#       dtype='object')

# %%
print(flight_plan["flightData.flightId.keys.estimatedOffBlockTime"].argmin())
print(flight_plan["flightData.estimatedTimeOfArrival"].argmax())
# Out:
# 77
# 416

# %%
flight_plan.iloc[416]
# Out:
# timestamp                                                                 2025-08-08 23:55:44.031000
# flightData.flightId.keys.aircraftId                                                           CCA865
# flightData.flightId.keys.aerodromeOfDestination                                                 LEMD
# flightData.flightId.keys.estimatedOffBlockTime                                   2025-08-08 23:00:00
# flightData.flightId.keys.aerodromeOfDeparture                                                   ZBAA
# flightData.flightId.id                                                                    AA73820119
# flightData.estimatedTimeOfArrival                                                2025-08-09 10:02:00
# flightData.aircraftAddress                                                                    7811A2
# flightData.icaoRoute                               K0956S0920 IDKEX B339 ASILA A575 INTIK/K0932S0...
# Name: 416, dtype: object

# %%
def delete_bad_cs(flight):
    from traffic.core import Flight
    if not isinstance(flight, Flight):
        return None
    cs = flight.callsign
    icao_pattern = re.compile(r"^[A-Z]{3}[0-9]+[A-Z]*$")
    return flight if bool(icao_pattern.match(cs.strip().upper())) else None

# %%
from datetime import datetime, timezone, timedelta
from traffic.data import eurofirs
from traffic.data import opensky
from pyopensky.schema import StateVectorsData4
from shapely.geometry import Polygon as ShapelyPolygon
from traffic.core import Traffic

adsb_df = Traffic.from_file("data/extract_edyy.parquet")

# start_adsb = datetime(2025, 8, 8, 0, 0, 0, tzinfo=timezone.utc)
# stop_adsb  = datetime(2025, 8, 8, 23, 59, 59, tzinfo=timezone.utc)

# delta_coords = [
#     (53.454167, 3.606111),
#     (52.733333, 5.583333),
#     (52.663333, 7.168889),
#     (51.193611, 5.521389),
#     (51.607778, 3.171944),
#     (51.480556, 3.171944),
#     (51.636944, 2.500000),
#     (51.455556, 2.500000),
#     (51.500000, 2.000000),
#     (51.950556, 2.356389)
# ]
# delta_geom = ShapelyPolygon([(lon, lat) for lat, lon in delta_coords])
# bbox = delta_geom.bounds

# # Server-side filters:
# # keep only rows above ~FL330 (≈ 10058 m). 
# alt_pred = (StateVectorsData4.baroaltitude >= 10000)

# # Only fetch columns you need
# cols = [
#     StateVectorsData4.time,         # epoch seconds
#     StateVectorsData4.lat,
#     StateVectorsData4.lon,
#     StateVectorsData4.baroaltitude,
#     StateVectorsData4.velocity,
#     StateVectorsData4.heading,
#     StateVectorsData4.icao24,
#     StateVectorsData4.callsign,
# ]

# # Chunk the day into smaller window
# chunk_minutes = 60
# chunks = pd.date_range(start_adsb, stop_adsb, freq=f"{chunk_minutes}min", inclusive="left")

# collected = []

# for t0 in chunks:
#     t1 = min(t0 + timedelta(minutes=chunk_minutes), stop_adsb)

#     trf = opensky.history(
#         start=t0,
#         stop=t1,
#         bounds=bbox,                       # tuple bbox -> cheaper for the backend
#         selected_columns=cols,             # fewer columns to ship
#     )

#     if trf is None:
#         continue

#     collected.append(trf)

# # Concatenate all chunks into one Traffic
# if collected:
#     adsb_df = collected[0]
#     for tr in collected[1:]:
#         adsb_df = adsb_df + tr
# else:
#     adsb_df = None

# if adsb_df is not None:
#     df = adsb_df.data
#     df.to_parquet("data/extract_edyy.parquet")
# else:
#     print("No data returned for the requested period/filters.")

# %%
icao24_with_fp = []

for cs in adsb_df.icao24:
    if cs.upper() in flight_plan["flightData.aircraftAddress"].values:
        icao24_with_fp.append(cs)
        
cs_with_fp = []

for cs in adsb_df.callsigns:
    if cs in flight_plan["flightData.flightId.keys.aircraftId"].values:
        cs_with_fp.append(cs)

filtered_adsb = adsb_df[cs_with_fp]

# %%
start, stop = filtered_adsb.data.timestamp.min(), filtered_adsb.data.timestamp.max()

print(start)
print(stop)
# Out:
# 2025-08-08 01:24:01+00:00
# 2025-08-08 23:59:59+00:00

# %% [markdown]
# # Detecting the matched cs within ATC communications.

# %%
import json

def save_transcripts_json(transcription, path):
    # convert datetime → iso string
    serializable = [
        [(ts.isoformat(), text) for ts, text in transcripts]
        for transcripts in transcription
    ]
    with open(path, "w") as f:
        json.dump(serializable, f, indent=2)
        
def load_transcripts_json(path):
    with open(path) as f:
        data = json.load(f)
    # convert iso → datetime
    return [
        [(datetime.fromisoformat(ts), text) for ts, text in transcripts]
        for transcripts in data
    ]
        
def save_callsign_comms_json(callsign_communications, path):
    serializable = {
        cs: [
            {
                "timestamp": entry["timestamp"].isoformat(),  # datetime → string
                "sentence": entry["sentence"],
                "detected": entry["detected"],
                "score": entry["score"],
            }
            for entry in entries
        ]
        for cs, entries in callsign_communications.items()
    }
    with open(path, "w") as f:
        json.dump(serializable, f, indent=2)
    
def load_callsign_comms_json(path):
    with open(path) as f:
        data = json.load(f)
    # convert iso → datetime
    return {
        cs: [
            {
                **entry,
                "timestamp": datetime.fromisoformat(entry["timestamp"])
            }
            for entry in entries
        ]
        for cs, entries in data.items()
    }

# %%
from utils.cs_matching import build_timestamp_range, closest_callsign_at_time
from utils_old.process_muac_audio import build_audio_catalog, transcribe_catalog

# base_dir = "/store/kruu/atc_muac/"

# adsb_ranges = build_timestamp_range(adsb_df)
# catalog = build_audio_catalog(
#     base_dir,
#     ("2025","08","08"),
#     sectors=["muac_delta_middle", "muac_delta_high"],
#     start=start, 
#     stop=stop,
#     max_workers=128,         
#     show_progress=True,  
# )
# print(len(catalog), "files downloaded")

# transcripts = transcribe_catalog(catalog)
# save_transcripts_json(transcripts, "data/transcripts_edyy.json")

# %%
from collections import defaultdict
from utils.cs_matching import merge_callsign_entities
from transformers import pipeline, AutoTokenizer, AutoModelForTokenClassification

# tokenizer_ner = AutoTokenizer.from_pretrained("Jzuluaga/bert-base-ner-atc-en-atco2-1h")
# model_ner = AutoModelForTokenClassification.from_pretrained("Jzuluaga/bert-base-ner-atc-en-atco2-1h")
# nlp = pipeline('ner', model=model_ner, tokenizer=tokenizer_ner, aggregation_strategy="first")

# # Nested lists can appear if VAD split
# transcript_flat = [item for sublist in transcripts for item in sublist]

# callsign_communications = defaultdict(list)

# for i, line in enumerate(transcript_flat):
#     timestamp = line[0]
#     sentence = line[1]
    
#     atco2_res = nlp(sentence)
#     atco2_res = merge_callsign_entities(atco2_res)
#     callsigns = [e for e in atco2_res if e['entity_group'] == 'callsign']
    
#     result = closest_callsign_at_time(
#         ner_callsigns = callsigns,               
#         traffic = adsb_df, # all adsb_data fetched to not have wrongly associated cs
#         adsb_ranges = adsb_ranges,
#         comm_time = timestamp,
#         match_threshold = 0.7,
#         # sector_geom = delta_geom,              
#         time_tolerance_s = 60,      
#     )
    
#     if result:
#         callsign_communications[result["best_context_match"]].append({
#             "timestamp": timestamp,
#             "sentence": sentence,
#             "detected": result["ner_detected_callsign"],
#             "score": result["match_score"]
#         })

# save_callsign_comms_json(callsign_communications, "data/callsign_communications_match.json")

# %%
transcripts = load_transcripts_json("data/transcripts_edyy.json")
callsign_communications = load_callsign_comms_json("data/callsign_communications_match.json")

# %%
com_with_fp = {}
for cs in cs_with_fp:
    if cs in callsign_communications.keys():
        com_with_fp[cs] = callsign_communications[cs]

save_callsign_comms_json(com_with_fp, "data/callsign_communications_flight_plan.json")

# %%
adsb_match_with_fp = adsb_df[com_with_fp.keys()]

# %%
adsb_match_with_fp
# Out:
#    icao24 callsign  count
# 0  43f6c4    2JEFF   3677
# 1  48548d  KLM1568   2190
# 2  485123    TRA8R   2162
# 3  3c6450   DLH5AK   1789
# 4  40643c  EZY87PC   1783
# 5  440c38  EJU76MB   1699
# 6  47c0d9  NSZ5085   1600
# 7  4ca73f    RYR4M   1579
# 8  39856d  AFR15HA   1547
# 9  4d2212  RYR9166   1521

# %%
com_with_fp
# Out:
# {'AFR96QH': [{'timestamp': datetime.datetime(2025, 8, 8, 20, 1, 44, tzinfo=datetime.timezone.utc),
#    'sentence': 'standing three control easy eight six four romeo yes just keep still and fly easy eight six five klm one two four kilo easy five six six five hotel going to liqal air france nine six quebec hotel good evening reaching three six zero down climbing to the right hand side three seven yankee yankee on course climbing flight level two three zero',
#    'detected': 'eight six five one two four kilo easy five six six five france nine six quebec hotel',
#    'score': 0.75},
#   {'timestamp': datetime.datetime(2025, 8, 8, 20, 4, 58, tzinfo=datetime.timezone.utc),
#    'sentence': 'hotel bravo ryan air nine six nine thank you request ahead one two two decimal two papa romeo papa romeo papa romeo now use affirmative air france nine six quebec hotel we re looking for flight level three eight zero three nine zero ok that s copied for now maintain flight level three six zero high altitude and descend from the climbing traffic at left right thousand feet above roger maintaining flight level three six zero air france nine six quebec hotel',
#    'detected': 'air france nine six quebec hotel',
#    'score': 1.0}],
#  'RYR39SD': [{'timestamp': datetime.datetime(2025, 8, 8, 21, 47, 50, tzinfo=datetime.timezone.utc),
#    'sentence': 'passing three nine three nine sierra delta level three seven zero contact runway three nine sierra delta',
#    'detected': 'three nine three nine sierra delta',
#    'score': 0.71}],
#  'KLM1568': [{'timestamp': datetime.datetime(2025, 8, 8, 22, 4, 12, tzinfo=datetime.timezone.utc),
#    'sentence': 'continue final time air klm eight five six',
#    'detected': 'klm eight five six',
#    'score': 0.97}],
#  'SAS4730': [{'timestamp': datetime.datetime(2025, 8, 8, 11, 3, 21, tzinfo=datetime.timezone.utc),
#    'sentence': 'five three two zero eight leaving flight level three six zero roger',
#    'detected': 'five three two zero eight',
#    'score': 0.77}],
#  'NOS5958': [{'timestamp': datetime.datetime(2025, 8, 8, 11, 0, 32, tzinfo=datetime.timezone.utc),
#    'sentence': 'hotel good morning flight level five five eight we re level three five zero on course navti',
#    'detected': 'five eight',
#    'score': 0.89},
#   {'timestamp': datetime.datetime(2025, 8, 8, 11, 2, 9, tzinfo=datetime.timezone.utc),
#    'sentence': 'ok sorry now so now we can start zero zero zero thank you and then five five two five able one thousand feet higher five five two five five five five and then maintain flight level three eight zero and call you back in two minutes ok bye',
#    'detected': 'five five five five',
#    'score': 0.81},
#   {'timestamp': datetime.datetime(2025, 8, 8, 11, 6, 10, tzinfo=datetime.timezone.utc),
#    'sentence': 'one three two seven eight five and direct to etihad one five six four three thank you',
#    'detected': 'one three two seven eight five',
#    'score': 0.85},
#   {'timestamp': datetime.datetime(2025, 8, 8, 11, 8, 33, tzinfo=datetime.timezone.utc),
#    'sentence': 'november five nine five eight let me just check for further restriction',
#    'detected': 'november five nine five eight',
#    'score': 0.85},
#   {'timestamp': datetime.datetime(2025, 8, 8, 11, 8, 58, tzinfo=datetime.timezone.utc),
#    'sentence': 'romeo thank you seven five thank you romeo',
#    'detected': 'seven five',
#    'score': 0.85},
#   {'timestamp': datetime.datetime(2025, 8, 8, 11, 13, 27, tzinfo=datetime.timezone.utc),
#    'sentence': 'partay hello only four five one victor flight level three one zero on climbing one one five',
#    'detected': 'four five one',
#    'score': 0.78}],
#  'EJU85AG': [{'timestamp': datetime.datetime(2025, 8, 8, 14, 21, 52, tzinfo=datetime.timezone.utc),
#    'sentence': 'zero alfa eight five alfa golf roger maintaining level three seven zero to woody',
#    'detected': 'zero alfa eight five alfa golf',
#    'score': 0.82},
#   {'timestamp': datetime.datetime(2025, 8, 8, 14, 22, 30, tzinfo=datetime.timezone.utc),
#    'sentence': 'al five eight five alfa golf level three four zero rate of descend one thousand feet per minute or more',
#    'detected': 'al five eight five alfa golf',
#    'score': 0.9},
#   {'timestamp': datetime.datetime(2025, 8, 8, 14, 22, 36, tzinfo=datetime.timezone.utc),
#    'sentence': 'descend flight level three four zero one thousand feet per minute or greater austrian eight five alfa golf',
#    'detected': 'austrian eight five alfa golf',
#    'score': 0.85}],
#  'EJU48MA': [{'timestamp': datetime.datetime(2025, 8, 8, 16, 16, 26, tzinfo=datetime.timezone.utc),
#    'sentence': 'alpine four eight mike alfa hello radar contact climb flight level three five zero to papa papa mike alfa mike alfa',
#    'detected': 'alpine four eight mike alfa',
#    'score': 0.76}],
#  'TAP780': [{'timestamp': datetime.datetime(2025, 8, 8, 10, 0, 3, tzinfo=datetime.timezone.utc),
#    'sentence': 'one two three decimal eight five zero czech air nine six zero nine good day',
#    'detected': 'czech air nine six zero nine',
#    'score': 0.74}],
#  'RYR30ED': [{'timestamp': datetime.datetime(2025, 8, 8, 20, 46, 37, tzinfo=datetime.timezone.utc),
#    'sentence': 'roger hello ryan air six zero alfa delta four hundred call us hello ryan air six zero alfa delta ready to go',
#    'detected': 'ryan air six zero alfa delta',
#    'score': 0.73}],
#  'EZY87PC': [{'timestamp': datetime.datetime(2025, 8, 8, 15, 33, 18, tzinfo=datetime.timezone.utc),
#    'sentence': 'easy eight seven papa charlie contact lufthansa one two eight decimal one six zero good bye one two eight one six zero easy eight seven papa charlie bye',
#    'detected': 'easy eight seven papa charlie',
#    'score': 1.0}],
#  'AFR94SY': [{'timestamp': datetime.datetime(2025, 8, 8, 14, 21, 37, tzinfo=datetime.timezone.utc),
#    'sentence': 'air france one four three yankee wizz air four three three zero inbound mikoc ground one four three yankee and we are left to right to speed right two two and standby for higher',
#    'detected': 'air france one four three yankee air four three three zero',
#    'score': 0.73}],
#  'KLM51N': [{'timestamp': datetime.datetime(2025, 8, 8, 19, 55, 42, tzinfo=datetime.timezone.utc),
#    'sentence': 'good evening klm five four november climbing flight level two five zero climbing five four november climbing flight level two nine zero arriba golf tango quebec climbing flight level two nine zero and affirm inbound golf tango tango',
#    'detected': 'klm five four november',
#    'score': 0.95}],
#  'RYR6NJ': [{'timestamp': datetime.datetime(2025, 8, 8, 9, 58, 20, tzinfo=datetime.timezone.utc),
#    'sentence': 'and thai nine three one three seven passing one thousand three three zero ryan air five papa juliett',
#    'detected': 'ryan air five papa juliett',
#    'score': 0.78},
#   {'timestamp': datetime.datetime(2025, 8, 8, 9, 59, 43, tzinfo=datetime.timezone.utc),
#    'sentence': 'direct kemad ryan air two papa juliett next to her',
#    'detected': 'ryan air two papa juliett',
#    'score': 0.75}],
#  'CBJ606': [{'timestamp': datetime.datetime(2025, 8, 8, 13, 24, 11, tzinfo=datetime.timezone.utc),
#    'sentence': 'aero five two one continue on point one zero continue on the flight level five two one aero five two one continue present heading ruzyne present heading down route six two one csa six zero six contact munz at one three seven decimal four six five',
#    'detected': 'csa six zero six',
#    'score': 0.75}],
#  'AFR57JJ': [{'timestamp': datetime.datetime(2025, 8, 8, 20, 6, 16, tzinfo=datetime.timezone.utc),
#    'sentence': 'air france five seven juliett flight level three five zero and route to pikot direct to lobby air france five seven juliett thank you',
#    'detected': 'air france five seven juliett',
#    'score': 0.94},
#   {'timestamp': datetime.datetime(2025, 8, 8, 20, 18, 14, tzinfo=datetime.timezone.utc),
#    'sentence': 'thank you have a good evening air france five seven juliett good bye air france five zero juliett three two six one three six decimal four six five one three six four six five air france five seven juliett thank you bye',
#    'detected': 'air france five seven juliett air france five zero juliett three two six one three six',
#    'score': 0.86}],
#  'SAS4657': [{'timestamp': datetime.datetime(2025, 8, 8, 15, 12, 16, tzinfo=datetime.timezone.utc),
#    'sentence': 'praha radar austrian two six six flight level three five zero to go to austrian two six six good afternoon contact',
#    'detected': 'austrian two six six',
#    'score': 0.73},
#   {'timestamp': datetime.datetime(2025, 8, 8, 15, 14, 32, tzinfo=datetime.timezone.utc),
#    'sentence': 'continue jobair eight three five nine',
#    'detected': 'eight three five nine',
#    'score': 0.75},
#   {'timestamp': datetime.datetime(2025, 8, 8, 15, 21, 44, tzinfo=datetime.timezone.utc),
#    'sentence': 'baltic one two four zero passing one seven six two two five clear to land three five baltic one six four seven good afternoon radar contact climb flight level three four zero climbing level three four zero baltic one two four zero',
#    'detected': 'baltic one six four seven',
#    'score': 0.77},
#   {'timestamp': datetime.datetime(2025, 8, 8, 15, 22, 36, tzinfo=datetime.timezone.utc),
#    'sentence': 'inbound polin eight three seven and inbound si',
#    'detected': 'eight three seven',
#    'score': 0.77},
#   {'timestamp': datetime.datetime(2025, 8, 8, 15, 25, 40, tzinfo=datetime.timezone.utc),
#    'sentence': 'dolik one two four seven continue climb flight level three six zero climb level three six zero direct to roger',
#    'detected': 'one two four seven',
#    'score': 0.74}],
#  'AFR92NG': [{'timestamp': datetime.datetime(2025, 8, 8, 17, 49, 48, tzinfo=datetime.timezone.utc),
#    'sentence': 'airbridge control good evening air france nine two november golf flight level three five zero to mudis',
#    'detected': 'airbridge control air france nine two november golf',
#    'score': 0.78},
#   {'timestamp': datetime.datetime(2025, 8, 8, 17, 49, 55, tzinfo=datetime.timezone.utc),
#    'sentence': 'air france nine two november golf one two eight decimal two eight fly heading zero five zero',
#    'detected': 'air france nine two november',
#    'score': 0.88},
#   {'timestamp': datetime.datetime(2025, 8, 8, 17, 50, 53, tzinfo=datetime.timezone.utc),
#    'sentence': 'air france nine two november golf turn left heading zero four zero',
#    'detected': 'air france nine two november golf',
#    'score': 1.0},
#   {'timestamp': datetime.datetime(2025, 8, 8, 17, 50, 57, tzinfo=datetime.timezone.utc),
#    'sentence': 'left heading zero four zero air france two nine two november golf',
#    'detected': 'france two nine two november golf',
#    'score': 0.89},
#   {'timestamp': datetime.datetime(2025, 8, 8, 17, 59, 32, tzinfo=datetime.timezone.utc),
#    'sentence': 'air france nine two november golf seems ready at travok to lagar echo delta yankee try to disconnect and lagar again echo delta yankee ok we try it air france nine two',
#    'detected': 'air france nine two november golf',
#    'score': 1.0},
#   {'timestamp': datetime.datetime(2025, 8, 8, 18, 0, 9, tzinfo=datetime.timezone.utc),
#    'sentence': 'air france nine two november left heading zero',
#    'detected': 'air france nine two',
#    'score': 0.77},
#   {'timestamp': datetime.datetime(2025, 8, 8, 18, 3, 1, tzinfo=datetime.timezone.utc),
#    'sentence': 'air france nine two november golf contact bratislava one three six decimal four six five bye bye',
#    'detected': 'air france nine two',
#    'score': 0.77}],
#  'SAS85T': [{'timestamp': datetime.datetime(2025, 8, 8, 20, 46, 26, tzinfo=datetime.timezone.utc),
#    'sentence': 'navigator eight five tango good evening flight level three eight zero ruzyne eight five tango ready',
#    'detected': 'eight five tango',
#    'score': 0.91},
#   {'timestamp': datetime.datetime(2025, 8, 8, 20, 50, 19, tzinfo=datetime.timezone.utc),
#    'sentence': 'austrian four four nine one tango tango climbing level three six zero passing level two one zero and we are proceeding to varik',
#    'detected': 'austrian four four nine one tango tango',
#    'score': 0.87},
#   {'timestamp': datetime.datetime(2025, 8, 8, 20, 54, 22, tzinfo=datetime.timezone.utc),
#    'sentence': 'german air eight five tango papa',
#    'detected': 'german air eight five tango papa',
#    'score': 0.72},
#   {'timestamp': datetime.datetime(2025, 8, 8, 20, 54, 27, tzinfo=datetime.timezone.utc),
#    'sentence': 'eight five tango alfa victor bye',
#    'detected': 'eight five tango alfa victor',
#    'score': 0.79}],
#  'FIN78Q': [{'timestamp': datetime.datetime(2025, 8, 8, 19, 45, 38, tzinfo=datetime.timezone.utc),
#    'sentence': 'proceed direct to victor and we will be requesting flight level three nine zero for now we have the cleared point inbound to india november and climb flight level three six zero roger climb flight level three six zero direct to india quebec seven two eight',
#    'detected': 'india quebec seven two eight',
#    'score': 0.71}],
#  'NSZ5079': [{'timestamp': datetime.datetime(2025, 8, 8, 9, 56, 36, tzinfo=datetime.timezone.utc),
#    'sentence': 'trian nine six zero nine descend flight level three six zero fifteen hundred feet per minute or more',
#    'detected': 'trian nine six zero nine',
#    'score': 0.71}],
#  'KLM33J': [{'timestamp': datetime.datetime(2025, 8, 8, 19, 53, 39, tzinfo=datetime.timezone.utc),
#    'sentence': 'passing level seven three three juliett climb two five zero for the traffic then pepik is ready at line up five climb flight level two nine zero speed five nine two climb flight level two nine zero inbound golf tango quebec',
#    'detected': 'three three juliett',
#    'score': 0.86}],
#  'RYR271F': [{'timestamp': datetime.datetime(2025, 8, 8, 19, 20, 6, tzinfo=datetime.timezone.utc),
#    'sentence': 'hotel golf tango quebec ryan air two seven one foxtrot',
#    'detected': 'hotel golf tango quebec ryan air two seven one foxtrot',
#    'score': 0.7}],
#  'SAS584': [{'timestamp': datetime.datetime(2025, 8, 8, 10, 55, 17, tzinfo=datetime.timezone.utc),
#    'sentence': 'passing that good day scandinavian five eight four climbing level three nine zero on a heading of zero three one',
#    'detected': 'scandinavian five eight four',
#    'score': 1.0}],
#  'AFR1799': [{'timestamp': datetime.datetime(2025, 8, 8, 19, 20, 18, tzinfo=datetime.timezone.utc),
#    'sentence': 'air france one two two approaching flight level two six zero inbound kolad request flight level three seven zero if available',
#    'detected': 'air france one two two',
#    'score': 0.71},
#   {'timestamp': datetime.datetime(2025, 8, 8, 19, 20, 45, tzinfo=datetime.timezone.utc),
#    'sentence': 'air france three three two and one zero two',
#    'detected': 'air france three three two',
#    'score': 0.7}],
#  'NSZ2889': [{'timestamp': datetime.datetime(2025, 8, 8, 21, 49, 8, tzinfo=datetime.timezone.utc),
#    'sentence': 'passing three eight nine at level three six zero and reducing romeo',
#    'detected': 'three eight nine',
#    'score': 0.73}],
#  'SAS1804': [{'timestamp': datetime.datetime(2025, 8, 8, 20, 45, 3, tzinfo=datetime.timezone.utc),
#    'sentence': 'praha good evening scandinavian one eight zero four flight level three seven zero inbound miknav hello scandinavian one eight zero four way to go',
#    'detected': 'scandinavian one eight zero four',
#    'score': 1.0}],
#  'SAS4685': [{'timestamp': datetime.datetime(2025, 8, 8, 16, 22, 8, tzinfo=datetime.timezone.utc),
#    'sentence': 'hello portugal six eight six flight level three two zero to charlie tango lima',
#    'detected': 'portugal six eight six',
#    'score': 0.7}],
#  'EZY14HC': [{'timestamp': datetime.datetime(2025, 8, 8, 11, 7, 10, tzinfo=datetime.timezone.utc),
#    'sentence': 'hotel good afternoon easy one four hotel charlie flight level three seven zero direct to ditis easy one four hotel charlie mike',
#    'detected': 'hotel good easy one four hotel charlie',
#    'score': 0.93}],
#  'SAS588': [{'timestamp': datetime.datetime(2025, 8, 8, 21, 6, 44, tzinfo=datetime.timezone.utc),
#    'sentence': 'two eight five contact munich one three three nine five five bye bye two three two five five five two eight five good day',
#    'detected': 'two eight five',
#    'score': 0.76}],
#  'RYR969': [{'timestamp': datetime.datetime(2025, 8, 8, 20, 2, 51, tzinfo=datetime.timezone.utc),
#    'sentence': 'roger good day ryan air nine six nine three two five climbing three five zero heading zero two zero degrees and yeah thank you we completely forgot thank you for the reminder will be ryan air nine six nine',
#    'detected': 'ryan air nine six nine',
#    'score': 1.0},
#   {'timestamp': datetime.datetime(2025, 8, 8, 20, 21, 29, tzinfo=datetime.timezone.utc),
#    'sentence': 'ryan air nine six hotel climbing level three five zero',
#    'detected': 'ryan air nine six',
#    'score': 0.97}],
#  'RYR52SV': [{'timestamp': datetime.datetime(2025, 8, 8, 17, 40, 41, tzinfo=datetime.timezone.utc),
#    'sentence': 'radar hello ryan air one victor alfa flight level three three zero inbound ryan air one victor alfa mike sierra is passing',
#    'detected': 'ryan air one victor alfa mike sierra',
#    'score': 0.76}],
#  'AFR53XE': [{'timestamp': datetime.datetime(2025, 8, 8, 13, 49, 48, tzinfo=datetime.timezone.utc),
#    'sentence': 'air france five three three xray echo request flight level three five zero final roger that copy',
#    'detected': 'air france five three three xray echo',
#    'score': 0.98},
#   {'timestamp': datetime.datetime(2025, 8, 8, 13, 51, 32, tzinfo=datetime.timezone.utc),
#    'sentence': 'air france five three two echo one six two go ahead air france five three two echo yeah keep the speed at maximum five or less alfa two six two is comming before the next five seven five or less for the next five minutes air france five three two echo',
#    'detected': 'air france five three two echo',
#    'score': 0.81},
#   {'timestamp': datetime.datetime(2025, 8, 8, 13, 54, 24, tzinfo=datetime.timezone.utc),
#    'sentence': 'air france five three three echo the heading for traffic on papa sierra ground continue left right heading level and you go right from eight miles behind and do you expect to descend i think we have any sight yes air france five three three echo thank you',
#    'detected': 'air france five three three echo',
#    'score': 0.82},
#   {'timestamp': datetime.datetime(2025, 8, 8, 13, 55, 18, tzinfo=datetime.timezone.utc),
#    'sentence': 'air france five three xray echo own altitude two six zero and reach two point three miknav via lima nine one nine five three november call you in later on cleared for ils approach five three xray so if you can fly to norkov direct me to sasavia seven five two two ok we ll try again air france five three xray',
#    'detected': 'air france five three xray',
#    'score': 0.9}],
#  'SWR3VD': [{'timestamp': datetime.datetime(2025, 8, 8, 13, 46, 31, tzinfo=datetime.timezone.utc),
#    'sentence': 'hello swiss three victor lima passing level one eight seven climbing level two five zero inbound kotmak csa three victor lima level five one climbing level three one zero and cross approaching flight level two five zero or above',
#    'detected': 'swiss three victor lima',
#    'score': 0.71}],
#  'SWR5DP': [{'timestamp': datetime.datetime(2025, 8, 8, 18, 30, tzinfo=datetime.timezone.utc),
#    'sentence': 'swiss five delta papa request climb level three one zero',
#    'detected': 'swiss five delta papa',
#    'score': 1.0}],
#  'TAP120Y': [{'timestamp': datetime.datetime(2025, 8, 8, 13, 17, 14, tzinfo=datetime.timezone.utc),
#    'sentence': 'air port one two zero yankee climb flight level three seven zero climbing flight level three seven zero air port one two zero yankee',
#    'detected': 'air port one two zero yankee',
#    'score': 0.74},
#   {'timestamp': datetime.datetime(2025, 8, 8, 13, 25, 32, tzinfo=datetime.timezone.utc),
#    'sentence': 'air portugal one two zero yankee contact me on one six decimal zero eight five three two zero eight five one two zero yankee',
#    'detected': 'air portugal one two zero yankee',
#    'score': 1.0}],
#  'AFR29AK': [{'timestamp': datetime.datetime(2025, 8, 8, 18, 3, 6, tzinfo=datetime.timezone.utc),
#    'sentence': 'one three six four two five air france nine two five localizer bye bye',
#    'detected': 'air france nine two five',
#    'score': 0.72}],
#  '2JEFF': [{'timestamp': datetime.datetime(2025, 8, 8, 10, 7, 32, tzinfo=datetime.timezone.utc),
#    'sentence': 'to foxtrot f request if able direct bevkoop via echo kilo six three uniform at the visual transition for information',
#    'detected': 'foxtrot f',
#    'score': 0.86},
#   {'timestamp': datetime.datetime(2025, 8, 8, 10, 7, 43, tzinfo=datetime.timezone.utc),
#    'sentence': 'yeah that s approved we can set the point to that that course is vemutu two foxtrot roger',
#    'detected': 'foxtrot roger',
#    'score': 0.71},
#   {'timestamp': datetime.datetime(2025, 8, 8, 10, 8, 15, tzinfo=datetime.timezone.utc),
#    'sentence': 'two foxtrot f after leaving descend flight level two six zero descend flight level two six zero two foxtrot f',
#    'detected': 'foxtrot f',
#    'score': 0.86},
#   {'timestamp': datetime.datetime(2025, 8, 8, 10, 53, 34, tzinfo=datetime.timezone.utc),
#    'sentence': 'foxtrot',
#    'detected': 'foxtrot',
#    'score': 0.9}],
#  'RYR6847': [{'timestamp': datetime.datetime(2025, 8, 8, 20, 40, 8, tzinfo=datetime.timezone.utc),
#    'sentence': 'roger hello ryan air six four seven three passing zero thousand tango good bye ryan air six four seven ready to go direct kilo papa',
#    'detected': 'ryan air six four seven three',
#    'score': 0.96},
#   {'timestamp': datetime.datetime(2025, 8, 8, 20, 47, 56, tzinfo=datetime.timezone.utc),
#    'sentence': 'ryan air eight seven five five juliett delta ro',
#    'detected': 'ryan air eight seven five five juliett delta ro',
#    'score': 0.72},
#   {'timestamp': datetime.datetime(2025, 8, 8, 20, 48, 4, tzinfo=datetime.timezone.utc),
#    'sentence': 'ryan air seven five eight two approaching holding point runway three five thank you direct to baltu ryan air seven five eight two',
#    'detected': 'ryan air seven five eight two',
#    'score': 0.93}],
#  'RYR54WW': [{'timestamp': datetime.datetime(2025, 8, 8, 13, 31, 21, tzinfo=datetime.timezone.utc),
#    'sentence': 'ryan air two one nine whiskey contact',
#    'detected': 'ryan air two one nine whiskey',
#    'score': 0.81}],
#  'SAS836': [{'timestamp': datetime.datetime(2025, 8, 8, 19, 16, 19, tzinfo=datetime.timezone.utc),
#    'sentence': 'air malta good evening scandinavian eight three six climbing flight level three nine zero inbound amado eight three six level in sight',
#    'detected': 'air malta good scandinavian eight three six',
#    'score': 0.73},
#   {'timestamp': datetime.datetime(2025, 8, 8, 19, 23, 58, tzinfo=datetime.timezone.utc),
#    'sentence': 'one three nine seven six arvek tower roger contact',
#    'detected': 'one three nine seven six',
#    'score': 0.74},
#   {'timestamp': datetime.datetime(2025, 8, 8, 19, 27, 51, tzinfo=datetime.timezone.utc),
#    'sentence': 'lux air two eight seven five two nine maintain three seven zero inbound to patko maintain three seven five three nine five two nine quebec seven three eight six flight level three eight zero',
#    'detected': 'nine five two nine quebec seven three eight six',
#    'score': 0.74},
#   {'timestamp': datetime.datetime(2025, 8, 8, 19, 28, 3, tzinfo=datetime.timezone.utc),
#    'sentence': 'good day we are able three eight direct oscar kilo',
#    'detected': 'three eight',
#    'score': 0.73}],
#  'SAS36E': [{'timestamp': datetime.datetime(2025, 8, 8, 21, 50, 23, tzinfo=datetime.timezone.utc),
#    'sentence': 'parture good evening scandinavian three six echo flight level three seven zero go back minimum three six by papa romeo delta',
#    'detected': 'scandinavian three six echo',
#    'score': 1.0}],
#  'KLM89Y': [{'timestamp': datetime.datetime(2025, 8, 8, 15, 36, 31, tzinfo=datetime.timezone.utc),
#    'sentence': 'praha sierra hello finn air eight yankee passing flight level one eight two climbing two five zero inbound krakow klm eight nine yankee hello radar contact climb flight level three four zero',
#    'detected': 'krakow eight nine yankee',
#    'score': 0.74}],
#  'AFR15HA': [{'timestamp': datetime.datetime(2025, 8, 8, 16, 50, 48, tzinfo=datetime.timezone.utc),
#    'sentence': 'praha good day ryan air eight eight bravo foxtrot two eight zero inbound odnem ryan air eight eight bravo foxtrot two eight zero nice bridge good evening air france one five hotel alfa flight level three six zero on confirm to land air france one five hotel alfa three six zero',
#    'detected': 'air france one five hotel alfa',
#    'score': 1.0},
#   {'timestamp': datetime.datetime(2025, 8, 8, 17, 10, 25, tzinfo=datetime.timezone.utc),
#    'sentence': 'hotel alfa xray seven two one climb flight level three nine zero',
#    'detected': 'hotel alfa xray seven two one',
#    'score': 0.72}],
#  'SAS560': [{'timestamp': datetime.datetime(2025, 8, 8, 20, 19, 13, tzinfo=datetime.timezone.utc),
#    'sentence': 'navigator hello scandinavian five six zero climbing level three five zero',
#    'detected': 'scandinavian five six zero',
#    'score': 1.0},
#   {'timestamp': datetime.datetime(2025, 8, 8, 20, 22, 11, tzinfo=datetime.timezone.utc),
#    'sentence': 'one six good evening thai nine four zero two climbing flight level three five zero thai nine four zero two hello radar departure direct to omelo climb level three seven zero we would like to keep for a while three five zero seven going to omelo is ok with you thai four zero two roger stop climbing three five zero still direct to omelo to omelo three five zero thank you very much thai nine four zero two',
#    'detected': 'thai nine four zero two',
#    'score': 0.7}],
#  'SAS4706': [{'timestamp': datetime.datetime(2025, 8, 8, 21, 17, 4, tzinfo=datetime.timezone.utc),
#    'sentence': 'parture good evening scandinavian five eight eight three nine zero inbound kesga scandinavian five eight eight hello radar contact with the eoT echo delta yankee yankee',
#    'detected': 'scandinavian five eight eight three nine zero scandinavian five eight eight echo delta yankee yankee',
#    'score': 0.71},
#   {'timestamp': datetime.datetime(2025, 8, 8, 21, 25, 46, tzinfo=datetime.timezone.utc),
#    'sentence': 'praha radar good evening scandinavian four seven zero six flight level three nine zero direct pepik scandinavian four seven zero six low level three nine zero',
#    'detected': 'scandinavian four seven zero six',
#    'score': 1.0}],
#  'AFR1797': [{'timestamp': datetime.datetime(2025, 8, 8, 13, 59, 28, tzinfo=datetime.timezone.utc),
#    'sentence': 'd india six six zero final direct to omelo speed bird one one nine thanks papa good afternoon air france one eight seven speed two five zero easy one seven zero air france one eight seven tower at left left continue present heading climb flight level three one zero roger level two one zero present heading air france one eight seven air france one eight seven report heading to mastic one three two decimal eight five thanks to you sir for reducing air france one eight seven',
#    'detected': 'air france one eight seven',
#    'score': 0.97},
#   {'timestamp': datetime.datetime(2025, 8, 8, 14, 2, 35, tzinfo=datetime.timezone.utc),
#    'sentence': 'air france one zero eight roger one two four four two zero two three zero',
#    'detected': 'air france one zero eight one two four four',
#    'score': 0.79}],
#  'RYR76PQ': [{'timestamp': datetime.datetime(2025, 8, 8, 17, 1, 39, tzinfo=datetime.timezone.utc),
#    'sentence': 'ryan air seven six papa quebec continue present heading as radar vector',
#    'detected': 'ryan air seven six papa quebec',
#    'score': 1.0},
#   {'timestamp': datetime.datetime(2025, 8, 8, 17, 7, 8, tzinfo=datetime.timezone.utc),
#    'sentence': 'ryan air seven six papa quebec when cleared weather you can resume your own navigation to kodok',
#    'detected': 'ryan air seven six papa quebec',
#    'score': 1.0},
#   {'timestamp': datetime.datetime(2025, 8, 8, 17, 7, 27, tzinfo=datetime.timezone.utc),
#    'sentence': 'ryan air seven six papa quebec we are cleared for the north road route direct kudok thank you',
#    'detected': 'ryan air seven six papa quebec',
#    'score': 1.0},
#   {'timestamp': datetime.datetime(2025, 8, 8, 17, 11, 32, tzinfo=datetime.timezone.utc),
#    'sentence': 'ryan air seven six papa quebec four miles three one two nine decimal seven three five good day one two nine seven three five ryan air seven six papa quebec good day',
#    'detected': 'ryan air seven six papa quebec',
#    'score': 1.0}],
#  'EJU76MB': [{'timestamp': datetime.datetime(2025, 8, 8, 13, 18, 51, tzinfo=datetime.timezone.utc),
#    'sentence': 'good morning bravo eight two five nine maintain flight level four one zero',
#    'detected': 'bravo eight two five nine',
#    'score': 0.78},
#   {'timestamp': datetime.datetime(2025, 8, 8, 13, 19, 8, tzinfo=datetime.timezone.utc),
#    'sentence': 'roger please bravo eight two five level bravo eight two five nine what point did you navigated into',
#    'detected': 'bravo eight two five level bravo eight two five nine',
#    'score': 0.73},
#   {'timestamp': datetime.datetime(2025, 8, 8, 13, 19, 16, tzinfo=datetime.timezone.utc),
#    'sentence': 'hotel victor hello speed bird eight five zero tango climbing flight level three four zero garlou and requesting three five zero please station calling standby bravo eight two five main level point de naviing in position la lari bravo eight two five landing inbound landing two five nine roger proceed direct papa then bravo uniform praha',
#    'detected': 'bravo eight',
#    'score': 0.78},
#   {'timestamp': datetime.datetime(2025, 8, 8, 13, 19, 40, tzinfo=datetime.timezone.utc),
#    'sentence': 'direct to bravo uniform bravo bravo eight two five',
#    'detected': 'bravo uniform bravo bravo eight two five',
#    'score': 0.73},
#   {'timestamp': datetime.datetime(2025, 8, 8, 13, 24, 57, tzinfo=datetime.timezone.utc),
#    'sentence': 'direct to kolad echo contact bravo eight two five',
#    'detected': 'bravo eight two five',
#    'score': 0.78}],
#  'RYR4M': [{'timestamp': datetime.datetime(2025, 8, 8, 14, 12, 36, tzinfo=datetime.timezone.utc),
#    'sentence': 'reach four one eight zero ryan air six mike mike reach four one eight zero ryan air eight five three',
#    'detected': 'ryan air six mike mike',
#    'score': 0.91}],
#  'IBE07FE': [{'timestamp': datetime.datetime(2025, 8, 8, 18, 39, 54, tzinfo=datetime.timezone.utc),
#    'sentence': 'five three kilo iberia three seven foxtrot echo approaching flight level three hundred',
#    'detected': 'five three kilo iberia three seven foxtrot echo',
#    'score': 0.76},
#   {'timestamp': datetime.datetime(2025, 8, 8, 18, 40, 8, tzinfo=datetime.timezone.utc),
#    'sentence': 'three five zero iberia zero seven foxtrot echo bye',
#    'detected': 'three five zero iberia zero seven foxtrot echo',
#    'score': 0.94}],
#  'SAS37A': [{'timestamp': datetime.datetime(2025, 8, 8, 19, 35, 26, tzinfo=datetime.timezone.utc),
#    'sentence': 'one three two seven eight five alfa lima one three four report further',
#    'detected': 'one three two seven eight five alfa lima one three four',
#    'score': 0.73}],
#  'SAS582': [{'timestamp': datetime.datetime(2025, 8, 8, 13, 58, 18, tzinfo=datetime.timezone.utc),
#    'sentence': 'for the heading the baltic one three two eight five bye bye roger stand continue',
#    'detected': 'baltic one three two eight five',
#    'score': 0.74},
#   {'timestamp': datetime.datetime(2025, 8, 8, 14, 3, 14, tzinfo=datetime.timezone.utc),
#    'sentence': 'beline two eight three roger inbound sasok',
#    'detected': 'two eight three',
#    'score': 0.71}],
#  'TRA8R': [{'timestamp': datetime.datetime(2025, 8, 8, 22, 29, 43, tzinfo=datetime.timezone.utc),
#    'sentence': 'frequency two seven seven seven romeo and three nine kilo cleared to land air france three seven alfa',
#    'detected': 'seven romeo',
#    'score': 0.71}],
#  'VKG4020': [{'timestamp': datetime.datetime(2025, 8, 8, 18, 26, 53, tzinfo=datetime.timezone.utc),
#    'sentence': 'charter three nine two three i can go ahead the nine two two echo proceed to pat pat and contact munchen one two four three five zero bye bye roger one three four decimal eight eight zero two three nine two three',
#    'detected': 'zero',
#    'score': 0.73}],
#  'NOZ96Q': [{'timestamp': datetime.datetime(2025, 8, 8, 17, 7, 43, tzinfo=datetime.timezone.utc),
#    'sentence': 'good evening norkin nine six quebec three six zero two mopit norkin nine six quebec three alfa',
#    'detected': 'norkin nine six quebec three six zero two nine six quebec three alfa',
#    'score': 0.75}],
#  'AFR1610': [{'timestamp': datetime.datetime(2025, 8, 8, 20, 1, 28, tzinfo=datetime.timezone.utc),
#    'sentence': 'good evening air france one six one zero climbing flight level three five zero',
#    'detected': 'air france one six one zero',
#    'score': 1.0},
#   {'timestamp': datetime.datetime(2025, 8, 8, 20, 9, 12, tzinfo=datetime.timezone.utc),
#    'sentence': 'air france five nine two can you give me an estimate of the position and the altitude',
#    'detected': 'air france five nine two',
#    'score': 0.71}],
#  'TRA6005': [{'timestamp': datetime.datetime(2025, 8, 8, 17, 54, 30, tzinfo=datetime.timezone.utc),
#    'sentence': 'five zero nine zero requested flight level three seven zero baltic two zero two ils two zero two direct kopit continue climb flight level three five zero and localizer delta yankee navy two',
#    'detected': 'five zero nine zero',
#    'score': 0.75}],
#  'NOZ3YO': [{'timestamp': datetime.datetime(2025, 8, 8, 21, 2, 57, tzinfo=datetime.timezone.utc),
#    'sentence': 'air malta good evening air berlin three yankee oscar three six zero inbound budal',
#    'detected': 'air malta good air berlin three yankee oscar three',
#    'score': 0.72}],
#  'RYR9166': [{'timestamp': datetime.datetime(2025, 8, 8, 18, 1, 50, tzinfo=datetime.timezone.utc),
#    'sentence': 'hotel xray good day ryan air nine one six six heading three six zero',
#    'detected': 'hotel xray ryan air nine one six six',
#    'score': 0.77},
#   {'timestamp': datetime.datetime(2025, 8, 8, 18, 19, 12, tzinfo=datetime.timezone.utc),
#    'sentence': 'ryan air four nine five with the squawk continue climb flight level three six zero',
#    'detected': 'ryan air four nine five',
#    'score': 0.91}],
#  'RYR8CP': [{'timestamp': datetime.datetime(2025, 8, 8, 19, 49, 29, tzinfo=datetime.timezone.utc),
#    'sentence': 'climbing flight level three one zero ryan air four eight eight papa',
#    'detected': 'ryan air four eight eight papa',
#    'score': 0.88},
#   {'timestamp': datetime.datetime(2025, 8, 8, 19, 57, 22, tzinfo=datetime.timezone.utc),
#    'sentence': 'control ryan air four eight eight papa p approaching flight level three three zero and request flight level three seven zero please',
#    'detected': 'ryan air four eight eight papa p',
#    'score': 0.87},
#   {'timestamp': datetime.datetime(2025, 8, 8, 19, 57, 36, tzinfo=datetime.timezone.utc),
#    'sentence': 'radar hello ryan air six four foxtrot alfa ready to descend easy five six four foxtrot report traffic ryan air four i take papa mike ready to descend and maintain two eight zero to be level one on the route sixty four foxtrot alfa',
#    'detected': 'ryan air four papa mike',
#    'score': 0.82},
#   {'timestamp': datetime.datetime(2025, 8, 8, 20, 0, 35, tzinfo=datetime.timezone.utc),
#    'sentence': 'one three two decimal two one zero ryan air four eight eight papa bye bye',
#    'detected': 'ryan air four eight eight papa',
#    'score': 0.88}],
#  'EWG38J': [{'timestamp': datetime.datetime(2025, 8, 8, 19, 41, 28, tzinfo=datetime.timezone.utc),
#    'sentence': 'now we are happy at three three zero euro trans three eight juliett thank you',
#    'detected': 'trans three eight juliett',
#    'score': 0.75}],
#  'DLH5AK': [{'timestamp': datetime.datetime(2025, 8, 8, 15, 17, 1, tzinfo=datetime.timezone.utc),
#    'sentence': 'asteri cargo lufthansa five alfa kilo flight level three six zero',
#    'detected': 'asteri cargo lufthansa five alfa kilo',
#    'score': 0.86},
#   {'timestamp': datetime.datetime(2025, 8, 8, 15, 17, 6, tzinfo=datetime.timezone.utc),
#    'sentence': 'lufthansa five alfa kilo good afternoon radar contact',
#    'detected': 'lufthansa five alfa kilo',
#    'score': 1.0}],
#  'KLM1641': [{'timestamp': datetime.datetime(2025, 8, 8, 19, 32, 17, tzinfo=datetime.timezone.utc),
#    'sentence': 'hotel good day klm one six four one passing two three one climbing two five zero inbound to klm one six four romeo via flight flight level three one zero climb flight level three one zero klm one six four',
#    'detected': 'klm one six four',
#    'score': 0.98},
#   {'timestamp': datetime.datetime(2025, 8, 8, 19, 32, 55, tzinfo=datetime.timezone.utc),
#    'sentence': 'confirm two seven zero for klm one six four one eight seven continue direct to rapet miro one three four',
#    'detected': 'klm one six four one eight seven',
#    'score': 0.93},
#   {'timestamp': datetime.datetime(2025, 8, 8, 19, 33, 17, tzinfo=datetime.timezone.utc),
#    'sentence': 'klm one six four one contact munchen one three two decimal eight five five one three two eight five klm one six four one',
#    'detected': 'klm one six four one',
#    'score': 1.0}],
#  'CHH758': [{'timestamp': datetime.datetime(2025, 8, 8, 10, 26, 59, tzinfo=datetime.timezone.utc),
#    'sentence': 'parture good morning hanat seven five eight passing flight level three zero zero to flight level three five zero hanat seven five eight quebec five',
#    'detected': 'hanat seven five eight',
#    'score': 0.75}],
#  'IBE09VT': [{'timestamp': datetime.datetime(2025, 8, 8, 14, 33, 48, tzinfo=datetime.timezone.utc),
#    'sentence': 'mike three kilo river yankee no nine victor tango maintaining flight level three four zero sierra papa confirm we have final traffic in via',
#    'detected': 'nine victor tango',
#    'score': 0.75}],
#  'FIN4BV': [{'timestamp': datetime.datetime(2025, 8, 8, 18, 15, 3, tzinfo=datetime.timezone.utc),
#    'sentence': 'parture good evening finn air four bravo victor flight level three two three climbing three five zero inbound helen finn air four bravo victor one two eight five good day good evening helen alfa finn air four bravo victor thank you',
#    'detected': 'finn air four bravo victor',
#    'score': 0.95}],
#  'FIN08PL': [{'timestamp': datetime.datetime(2025, 8, 8, 15, 53, 48, tzinfo=datetime.timezone.utc),
#    'sentence': 'hotel lima kilo finn air three eight papa lima maintain flight level three zero zero on course holding standard zero eight papa lima kilo ready for taxi',
#    'detected': 'hotel lima kilo finn air three eight papa lima',
#    'score': 0.71}],
#  'NSZ9LV': [{'timestamp': datetime.datetime(2025, 8, 8, 20, 42, 53, tzinfo=datetime.timezone.utc),
#    'sentence': 'hotel zulu echo good day romeo nine lima victor level four hundred inbound komei present lima victor ready to land three two two one zero bye bye waiting for wizz air two two',
#    'detected': 'lima victor',
#    'score': 0.78}],
#  'AFR37ZW': [{'timestamp': datetime.datetime(2025, 8, 8, 14, 22, 3, tzinfo=datetime.timezone.utc),
#    'sentence': 'air france three seven zulu whiskey descend flight level three four zero',
#    'detected': 'air france three seven zulu whiskey',
#    'score': 1.0}],
#  'NSZ3675': [{'timestamp': datetime.datetime(2025, 8, 8, 21, 14, 3, tzinfo=datetime.timezone.utc),
#    'sentence': 'csa five six seven roger that is copied left turn heading north left turn heading north and can we level two nine zero csa five six seven apron descend flight level two nine zero climb to flight two nine zero and left turn heading north from time vfr six seven zero after a good evening one five nine whiskey climb flight level three five zero climb flight level three one and we are out of here',
#    'detected': 'csa five six seven',
#    'score': 0.79},
#   {'timestamp': datetime.datetime(2025, 8, 8, 21, 15, 34, tzinfo=datetime.timezone.utc),
#    'sentence': 'sudanair five six seven seven proceed direct to ribert ribert direct five six seven seven',
#    'detected': 'direct five six seven seven',
#    'score': 0.77},
#   {'timestamp': datetime.datetime(2025, 8, 8, 21, 18, 28, tzinfo=datetime.timezone.utc),
#    'sentence': 'five six seven seven descend flight level two five zero descend two five zero five six seven seven',
#    'detected': 'five six seven seven',
#    'score': 0.77}],
#  'SAS4686': [{'timestamp': datetime.datetime(2025, 8, 8, 20, 54, 10, tzinfo=datetime.timezone.utc),
#    'sentence': 'praha six hello scandinavian four six eight six flight level three nine zero for rapet four six eight six hello radar contact',
#    'detected': 'six scandinavian four six eight six',
#    'score': 0.99},
#   {'timestamp': datetime.datetime(2025, 8, 8, 20, 54, 29, tzinfo=datetime.timezone.utc),
#    'sentence': 'thank you sir five six five three five',
#    'detected': 'five six five three five',
#    'score': 0.72},
#   {'timestamp': datetime.datetime(2025, 8, 8, 20, 54, 41, tzinfo=datetime.timezone.utc),
#    'sentence': 'maintaining flight level three eight zero for now scandinavian eight five five',
#    'detected': 'scandinavian eight five five',
#    'score': 0.89},
#   {'timestamp': datetime.datetime(2025, 8, 8, 21, 10, 27, tzinfo=datetime.timezone.utc),
#    'sentence': 'we request three three zero siberia five six seven seven',
#    'detected': 'five six seven seven',
#    'score': 0.78}],
#  'TOM94Y': [{'timestamp': datetime.datetime(2025, 8, 8, 16, 42, 28, tzinfo=datetime.timezone.utc),
#    'sentence': 'proceed nine four yankee ke',
#    'detected': 'proceed nine four yankee',
#    'score': 0.76}],
#  'AFR1764': [{'timestamp': datetime.datetime(2025, 8, 8, 18, 34, 14, tzinfo=datetime.timezone.utc),
#    'sentence': 'proceed good evening air france one seven six four we are reaching three five zero inbound lokka air france one seven six four seven five three',
#    'detected': 'air france one seven six four',
#    'score': 1.0},
#   {'timestamp': datetime.datetime(2025, 8, 8, 18, 44, 19, tzinfo=datetime.timezone.utc),
#    'sentence': 'air france one seven six four contact nor shuttle one three six decimal four six one three six four six five air france one seven six four good evening',
#    'detected': 'air france one seven six four',
#    'score': 1.0}],
#  'AFR1462': [{'timestamp': datetime.datetime(2025, 8, 8, 19, 25, 15, tzinfo=datetime.timezone.utc),
#    'sentence': 'marsa good evening air france one four six two climbing flight level three five zero',
#    'detected': 'air france one four six two',
#    'score': 1.0},
#   {'timestamp': datetime.datetime(2025, 8, 8, 19, 25, 49, tzinfo=datetime.timezone.utc),
#    'sentence': 'good evening air france one four six two',
#    'detected': 'air france one four six two',
#    'score': 1.0},
#   {'timestamp': datetime.datetime(2025, 8, 8, 19, 29, 2, tzinfo=datetime.timezone.utc),
#    'sentence': 'air france one four six two requesting final level three seven zero',
#    'detected': 'air france one four six two',
#    'score': 1.0}],
#  'NSZ5085': [{'timestamp': datetime.datetime(2025, 8, 8, 9, 7, 22, tzinfo=datetime.timezone.utc),
#    'sentence': 'parture charlie alfa alfa three five zero with heading one five',
#    'detected': 'five zero',
#    'score': 0.75}],
#  'NOZ97B': [{'timestamp': datetime.datetime(2025, 8, 8, 19, 54, 6, tzinfo=datetime.timezone.utc),
#    'sentence': 'one three two zero eight five is direct pike four nine seven bravo thank you',
#    'detected': 'pike four nine seven bravo',
#    'score': 0.73}]}
