# %%
import os
import json
import pandas as pd
from datetime import datetime, timezone
from pathlib import Path

from traffic.core import Traffic

from utils.process_audio import ATCFileMeta, AudioCatalog
from pydub import AudioSegment

output_dir = "outputs/20250831"

# %%
def load_transcripts_json(path):
    with open(path) as f:
        data = json.load(f)
    # convert iso → datetime
    return [
        [(datetime.fromisoformat(ts), text) for ts, text in transcripts]
        for transcripts in data
    ]

def load_callsign_comms_json(path):
    with open(path) as f:
        data = json.load(f)
    # convert iso → datetime
    return {
        cs: [
            {
                **entry,
                "timestamp": datetime.fromisoformat(entry["timestamp"])
            }
            for entry in entries
        ]
        for cs, entries in data.items()
    }
    
def load_audio_catalog_from_json(path: str | Path,
                                    target_sr: int = 16000,
                                    mono: bool = True) -> AudioCatalog:
        """
        Reload a catalog from JSON (previously saved with only ATCFileMeta).
        Returns list of (ATCFileMeta, AudioSegment).
        """
        with open(path, "r") as f:
            data = json.load(f)

        catalog: AudioCatalog = []
        for entry in data:
            meta = ATCFileMeta(
                sector=entry["sector"],
                dt=datetime.fromisoformat(entry["dt"]).replace(tzinfo=timezone.utc),
                freq_hz=int(entry["freq_hz"]),
                freq_mhz=float(entry["freq_mhz"]),
                ext=entry["ext"],
                original_name=entry["original_name"],
                path=entry["path"],
            )

            # reload audio
            seg = AudioSegment.from_file(meta.path)
            if mono:
                seg = seg.set_channels(1)
            if target_sr:
                seg = seg.set_frame_rate(target_sr)

            catalog.append((meta, seg))

        # sort by timestamp just in case
        catalog.sort(key=lambda item: item[0].dt)
        return catalog

# %%
# catalog = load_audio_catalog_from_json(os.path.join(output_dir, "catalog.json"))
callsigns_coms = pd.read_parquet(os.path.join(output_dir, "callsign_comms.parquet"))
adsb = Traffic.from_file(os.path.join(output_dir, "adsb.parquet"))
transcripts = load_transcripts_json(os.path.join(output_dir, "transcripts.json"))
# flight_plan = pd.read_csv(os.path.join(output_dir, "extract_edyy_25_august.csv"))

# %% [markdown]
# ****
# # Identified Communications
# ****

# %% [markdown]
# Good conversations for the paper:
# - SAS66P on 25/08
# - UAE59T on 31/08
# - LOT274 on 31/08
# - AFR75BQ on 31/08
# - UAL933 on 31/08
# - DLH8P  on 31/08
#
# Avec Heading insturctions on 31/08:
# - DLH8P, LOT274, RYR7DP, UAL933, AFR74BQ, (~EXS321P)

# %%
callsigns_coms
# Out:
#      callsign                 timestamp  \
# 0        None 2025-08-31 00:00:01+00:00
# 1        None 2025-08-31 00:01:04+00:00
# 2        None 2025-08-31 00:01:50+00:00
# 3     EXS11MG 2025-08-31 00:01:55+00:00
# 4        None 2025-08-31 00:02:06+00:00
# ...       ...                       ...
# 6030  EXS79WU 2025-08-31 23:59:27+00:00
# 6031     None 2025-08-31 23:59:29+00:00
# 6032     None 2025-08-31 23:59:38+00:00
# 6033  EXS79WU 2025-08-31 23:59:46+00:00
# 6034     None 2025-08-31 23:59:57+00:00
#
#                                                sentence  \
# 0                                            three five
# 1        zero nine one zero nine siberia nine five five
# 2     lot three quebec one one mike golf flight leve...
# 3             channex one one mike golf lower than five
# 4     praha good morning united nine one flight leve...
# ...                                                 ...
# 6030      yes seven nine whiskey uniform any turbulence
# 6031  yeah we have just experienced occasional moder...
# 6032  ok that copied that what was reported before a...
# 6033  roger thank you channex seven nine whiskey uni...
# 6034                          ok we can expect a report
#
#                                                detected  score  matched
# 0                                            three five    NaN    False
# 1        zero nine one zero nine siberia nine five five    NaN    False
# 2                         lot three quebec one one mike    NaN    False
# 3                                  channex one one mike   0.74     True
# 4                                       united nine one    NaN    False
# ...                                                 ...    ...      ...
# 6030                     yes seven nine whiskey uniform   0.83     True
# 6031                                               None    NaN    False
# 6032                                               None    NaN    False
# 6033  channex seven nine whiskey uniform channex six...   0.89     True
# 6034                                               None    NaN    False
#
# [6035 rows x 6 columns]

# %%
callsigns_coms.query("matched == True").callsign.value_counts()
# Out:
# callsign
# DLH415     23
# DLH419     17
# WUK9109    16
# DLH846     16
# BOX459     14
#            ..
# CSN347      1
# UPS222      1
# AAL704      1
# HYS711      1
# KLM48       1
# Name: count, Length: 1277, dtype: int64

# %%
callsigns_coms.query("score == 1").callsign.value_counts()[15:30]
# Out:
# callsign
# CSN348     5
# SAS1600    5
# RYR644Z    5
# RYR394L    5
# SWR1E      5
# DLH2K      5
# AFR1610    4
# CCA934     4
# DLH974     4
# EZY8649    4
# UAL169     4
# RYR52MW    4
# UAE59T     4
# AIC144     4
# SWR2DV     4
# Name: count, dtype: int64

# %%
adsb["DLH415"] | adsb["DLH8P"]
# Out:
# Several flight_ids for one flight, consider splitting
# Several flight_ids for one flight, consider splitting
#     <div style='
#         margin: 1ex;
#         min-width: 250px;
#         max-width: 300px;
#         display: inline-block;
#         vertical-align: top;'>
#         <h4><b>Flight</b> {'DLH415_636', 'DLH415_637'}</h4><ul><li><b>callsign:</b> DLH415   </li><li><b>aircraft:</b> <code>3c65a1</code> · 🇩🇪 D-AIMA (A388)</li><li><b>start:</b> 2025-08-31 08:50:30+00:00</li><li><b>stop:</b> 2025-08-31 15:21:00+00:00</li><li><b>duration:</b> 0 days 06:30:30</li><li><b>sampling rate:</b> 13 second(s)</li></ul><div style="white-space: nowrap"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="300" height="300" viewBox="-215784.99725114615 -173172.04044677064 442691.05060649046 352799.00298602006" preserveAspectRatio="xMinYMin meet"><g transform="matrix(1,0,0,-1,0,6454.92209247881)"><polyline fill="none" stroke="#66cc99" stroke-width="2951.2736707099366" points="-161740.24307493784,-153713.516839058 -150457.25523030185,-156776.07560949321 -120677.6990615356,-153247.7962455426 -90927.29038115626,-149542.43367861983 -61207.13977535995,-145660.10796691105 -31535.614663997676,-141603.35856966418 -1138.5217668664893,-137259.4729410612 29222.381308240423,-132730.22925059748 59545.90271475208,-128015.80460114412 89813.71787356948,-123119.21003066174 120058.93368648824,-118035.09016085551 150246.1269707346,-112769.40049040568 180408.27518783836,-107316.39043083937 210510.0885180669,-101682.44231596662 154315.12218922083,-65475.5206252293 122087.16616719747,-41830.21554736454 90165.80366971596,-17975.752873249185 82551.24700657059,-12190.890651568689 73213.7547170282,-5771.269279694704 20951.141600620555,25419.130897767023 6121.27579519068,34332.715235285585 -21220.10598032455,50949.498464227094 -48374.5482439399,67719.0765718884 -63638.56981355307,77249.98421989578 -78842.5438390021,86828.85151139252 -93986.32045780474,96455.37198690654 -109069.75128582779,106129.2385960441 -122416.38765704996,114500.69344940537 -135716.68929673362,122909.05108478275 -148970.55505598072,131354.1029815183 -199389.03241386873,163230.99770197202" opacity="0.8" /></g></svg></div>
#     </div>
#
#     <div style='
#         margin: 1ex;
#         min-width: 250px;
#         max-width: 300px;
#         display: inline-block;
#         vertical-align: top;'>
#         <h4><b>Flight</b> DLH8P_638</h4><ul><li><b>callsign:</b> DLH8P   </li><li><b>aircraft:</b> <code>3c65a1</code> · 🇩🇪 D-AIMA (A388)</li><li><b>start:</b> 2025-08-31 14:49:28+00:00</li><li><b>stop:</b> 2025-08-31 15:20:57+00:00</li><li><b>duration:</b> 0 days 00:31:29</li><li><b>sampling rate:</b> 3 second(s)</li></ul><div style="white-space: nowrap"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="300" height="300" viewBox="-215786.00032011984 -144513.80975455462 442728.4986231081 297683.6952681838" preserveAspectRatio="xMinYMin meet"><g transform="matrix(1,0,0,-1,0,8656.075759074534)"><polyline fill="none" stroke="#66cc99" stroke-width="2951.523324154054" points="210545.14650213238,-128116.45795369877 210545.14650213238,-128116.45795369877 210545.14650213238,-128116.45795369877 210545.14650213238,-128116.45795369877 210545.14650213238,-128116.45795369877 210545.14650213238,-128116.45795369877 210545.14650213238,-128116.45795369877 210545.14650213238,-128116.45795369877 210545.14650213238,-128116.45795369877 210545.14650213238,-128116.45795369877 210545.14650213238,-128116.45795369877 210545.14650213238,-128116.45795369877 202786.5840628285,-123123.98012972999 202786.5840628285,-123123.98012972999 202786.5840628285,-123123.98012972999 202786.5840628285,-123123.98012972999 202786.5840628285,-123123.98012972999 202786.5840628285,-123123.98012972999 202786.5840628285,-123123.98012972999 202786.5840628285,-123123.98012972999 202786.5840628285,-123123.98012972999 196216.7772061546,-118892.34860404172 196216.7772061546,-118892.34860404172 196216.7772061546,-118892.34860404172 196216.7772061546,-118892.34860404172 196216.7772061546,-118892.34860404172 196216.7772061546,-118892.34860404172 196216.7772061546,-118892.34860404172 196216.7772061546,-118892.34860404172 189306.74189462548,-114447.65102015596 189306.74189462548,-114447.65102015596 189306.74189462548,-114447.65102015596 189306.74189462548,-114447.65102015596 189306.74189462548,-114447.65102015596 189306.74189462548,-114447.65102015596 189306.74189462548,-114447.65102015596 189306.74189462548,-114447.65102015596 189306.74189462548,-114447.65102015596 189306.74189462548,-114447.65102015596 189306.74189462548,-114447.65102015596 189306.74189462548,-114447.65102015596 189306.74189462548,-114447.65102015596 189306.74189462548,-114447.65102015596 189306.74189462548,-114447.65102015596 189306.74189462548,-114447.65102015596 189306.74189462548,-114447.65102015596 189306.74189462548,-114447.65102015596 189306.74189462548,-114447.65102015596 175654.60550059355,-105650.05543104773 175654.60550059355,-105650.05543104773 175654.60550059355,-105650.05543104773 175654.60550059355,-105650.05543104773 172714.1325325312,-103755.1054462875 172714.1325325312,-103755.1054462875 172714.1325325312,-103755.1054462875 172714.1325325312,-103755.1054462875 172714.1325325312,-103755.1054462875 172714.1325325312,-103755.1054462875 172714.1325325312,-103755.1054462875 172714.1325325312,-103755.1054462875 172714.1325325312,-103755.1054462875 172714.1325325312,-103755.1054462875 172714.1325325312,-103755.1054462875 172714.1325325312,-103755.1054462875 172714.1325325312,-103755.1054462875 172714.1325325312,-103755.1054462875 172714.1325325312,-103755.1054462875 172714.1325325312,-103755.1054462875 172714.1325325312,-103755.1054462875 155647.2686373105,-92762.72321260278 154337.46284040663,-91922.57359809078 154337.46284040663,-91922.57359809078 154337.46284040663,-91922.57359809078 154337.46284040663,-91922.57359809078 154337.46284040663,-91922.57359809078 154337.46284040663,-91922.57359809078 154337.46284040663,-91922.57359809078 154337.46284040663,-91922.57359809078 154337.46284040663,-91922.57359809078 154337.46284040663,-91922.57359809078 154337.46284040663,-91922.57359809078 154337.46284040663,-91922.57359809078 154337.46284040663,-91922.57359809078 154337.46284040663,-91922.57359809078 154337.46284040663,-91922.57359809078 154337.46284040663,-91922.5735980 ...

# %%
cs = "LOT274"
cs_conv = callsigns_coms.query(f"callsign == '{cs}'")
for _, l in cs_conv.iterrows():
    print(l["timestamp"], l["sentence"])
# cs_conv.to_csv("DLH8P.csv")
# Out:
# 2025-08-31 18:07:29+00:00 lot two seven four call you identified climb flight level three two zero
# 2025-08-31 18:07:34+00:00 climb flight level three two zero lot two seven four
# 2025-08-31 18:08:16+00:00 lot two seven four climb now flight level three three zero
# 2025-08-31 18:08:19+00:00 climb flight level three three zero lot two seven four
# 2025-08-31 18:16:07+00:00 lot two seven four turn left on heading zero seven zero
# 2025-08-31 18:20:33+00:00 lot two seven four if possible we would like to climb three seven zero
# 2025-08-31 18:20:39+00:00 lot two seven four roger climb now flight level three six zero
# 2025-08-31 18:20:44+00:00 climb flight level three six zero lot two seven four

# %%
# start = datetime(2025, 8, 31, 8, 26, 0, tzinfo=timezone.utc)
# stop  = datetime(2025, 8, 31, 8, 58, 0, tzinfo=timezone.utc)

# cond = (start < callsigns_coms.timestamp) & (callsigns_coms.timestamp < stop)
# callsigns_coms[cond].to_csv("test.csv")

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from datetime import timedelta

cs = 'LOT274'

comms_df = callsigns_coms.query(f"callsign == '{cs}'").copy()
comms_df["timestamp"] = pd.to_datetime(comms_df["timestamp"], utc=True)
comm_times = sorted(comms_df["timestamp"].dropna().unique())

cmin, cmax = comm_times[0], comm_times[-1]

pad = timedelta(minutes=5)
f = adsb[cs]

df_fl = f.data.copy()
df_fl = df_fl.sort_values("timestamp")

if "altitude" not in df_fl and "baroaltitude" in df_fl:
    df_fl["altitude"] = df_fl["baroaltitude"] * 3.28084  # m -> ft
if "groundspeed" not in df_fl and "velocity" in df_fl:
    df_fl["groundspeed"] = df_fl["velocity"] * 1.94384   # m/s -> kt

# 4) Plot
fig, ax1 = plt.subplots(figsize=(14, 6))

ax1.plot(df_fl["timestamp"], df_fl["altitude"], label="Altitude (ft)")
ax1.set_ylabel("Altitude (ft)")
ax1.set_ylim(0, max(30000, df_fl["altitude"].max() * 1.1))
ax1.grid(True, which='both', linestyle='--', linewidth=0.5, alpha=0.7)

ax2 = ax1.twinx()
ax2.plot(df_fl["timestamp"], df_fl["groundspeed"], label="Groundspeed (kt)", color="orange")
ax2.set_ylabel("Groundspeed (kt)")
ax2.set_ylim(100, max(400, df_fl["groundspeed"].max() * 1.1))

# Vertical markers at each comm
for ts in comm_times:
    ax1.axvline(ts, color="red", linestyle="--", linewidth=1, alpha=0.7)

# # Optional: annotate a few comms (e.g., first 3)
# for _, row in comms_df.head(3).iterrows():
#     ax1.annotate(
#         row["detected"],
#         xy=(row["timestamp"], ax1.get_ylim()[1] * 0.95),
#         xytext=(5, -5),
#         textcoords="offset points",
#         fontsize=9,
#         rotation=0,
#         ha="left", va="top",
#         bbox=dict(boxstyle="round,pad=0.2", fc="white", ec="none", alpha=0.7)
#     )

# X-axis formatting
ax1.xaxis.set_major_formatter(mdates.DateFormatter('%H:%M'))
ax1.set_xlabel("Time (UTC)")
plt.title("DLH968 — Altitude & Groundspeed with ATC Communications")

# De-clutter spines
for spine in ["top", "right", "left"]:
    ax1.spines[spine].set_visible(False)
    ax2.spines[spine].set_visible(False)

plt.tight_layout()
plt.show()

# %%
from ipyleaflet import Marker, Polygon, Rectangle
import math
from shapely.geometry import Polygon as ShapelyPolygon

delta_coords = [
    (53.454167, 3.606111),
    (52.733333, 5.583333),
    (52.663333, 7.168889),
    (51.193611, 5.521389),
    (51.607778, 3.171944),
    (51.480556, 3.171944),
    (51.636944, 2.500000),
    (51.455556, 2.500000),
    (51.500000, 2.000000),
    (51.950556, 2.356389)
]
delta_geom = ShapelyPolygon([(lon, lat) for lat, lon in delta_coords])
W, S, E, N = delta_geom.bounds      
# Add a buffer layer around delta sector
# 1° lat ≈ 111.32 km; 1° lon ≈ 111.32 km * cos(latitude)
buffer_km = 50.0 # Roughly 4min at 400kts
lat_c = delta_geom.centroid.y
deg_lat = buffer_km / 111.32
deg_lon = buffer_km / (111.32 * math.cos(math.radians(lat_c)))

bbox_buffered = (W - deg_lon, S - deg_lat, E + deg_lon, N + deg_lat)  # (west, south, east, north)

m = f.map_leaflet()

for ts in comm_times:
    if f.at(ts) is not None:
        marker = Marker(location=(f.at(ts).latitude, f.at(ts).longitude))
        m.add(marker)

polygon = Polygon(
    locations=delta_coords + [delta_coords[0]],
    color="red",
    fill_color="red",
    fill_opacity=0.2,
    weight=3,
    name="Sector bounds"
)

bbox_rect = Rectangle(
    bounds=((bbox_buffered[1], bbox_buffered[0]), (bbox_buffered[3], bbox_buffered[2])),
    color="orange",
    fill_color="orange",
    fill_opacity=0.1,
    weight=2,
    name="OpenSky bbox"
)

m.add_layer(polygon)
m.add_layer(bbox_rect)
m
# Out:
# Map(center=[52.69536432548175, 4.668353293473562], controls=(ZoomControl(options=['position', 'zoom_in_text', …

# %% [markdown]
# ****
# # Flights with Flight plan
# ****

# %%
# Last message recieved by the NM
flight_plan["timestamp"] = flight_plan["timestamp"].str.replace(
    r" (\d{3})$", r".\1", regex=True
)
flight_plan["timestamp"] = pd.to_datetime(flight_plan["timestamp"])

# Estimated departure time
flight_plan["flightData.flightId.keys.estimatedOffBlockTime"] = flight_plan["flightData.flightId.keys.estimatedOffBlockTime"].str.replace(
    r" (\d{3})$", r".\1", regex=True
)
flight_plan["flightData.flightId.keys.estimatedOffBlockTime"] = pd.to_datetime(flight_plan["flightData.flightId.keys.estimatedOffBlockTime"])

# Estimated arrival time
flight_plan["flightData.estimatedTimeOfArrival"] = flight_plan["flightData.estimatedTimeOfArrival"].str.replace(
    r" (\d{3})$", r".\1", regex=True
)
flight_plan["flightData.estimatedTimeOfArrival"] = pd.to_datetime(flight_plan["flightData.estimatedTimeOfArrival"])

flight_plan.columns
# Out:
# Index(['timestamp', 'flightData.flightId.keys.aircraftId',
#        'flightData.flightId.keys.aerodromeOfDestination',
#        'flightData.flightId.keys.estimatedOffBlockTime',
#        'flightData.flightId.keys.aerodromeOfDeparture',
#        'flightData.flightId.id', 'flightData.estimatedTimeOfArrival',
#        'flightData.aircraftAddress', 'flightData.icaoRoute'],
#       dtype='object')

# %%
icao24_with_fp = []

for cs in adsb.icao24:
    if cs.upper() in flight_plan["flightData.aircraftAddress"].values:
        icao24_with_fp.append(cs)
        
cs_with_fp = []

for cs in adsb.callsigns:
    if cs in flight_plan["flightData.flightId.keys.aircraftId"].values:
        cs_with_fp.append(cs)

filtered_coms = callsigns_coms.query(f"callsign.isin({cs_with_fp})")
filtered_coms.to_parquet("outputs/20250825/callsign_communications_flight_plan.parquet")

# %%
len(filtered_coms.callsign.unique())
# Out:
# 191

# %%
filtered_coms.callsign.value_counts()
# Out:
# callsign
# AFR1610    10
# SAS588      9
# SAS4703     9
# SAS2773     8
# AFR1462     7
#            ..
# TVF55PJ     1
# VOE2119     1
# NOZ1487     1
# TAY7TL      1
# EJU3968     1
# Name: count, Length: 191, dtype: int64

# %%
filtered_coms.query("score == 1").callsign.value_counts()
# Out:
# callsign
# AFR1610    8
# SAS588     5
# KLM1641    4
# RYR6NJ     3
# SAS63Y     3
#           ..
# NOZ97B     1
# NOZ1487    1
# NSZ4MF     1
# AFR67ZC    1
# TAY7TL     1
# Name: count, Length: 86, dtype: int64

# %% [markdown]
# ****
# # Identified conflict
# ****

# %%
deconf_id = ["AA74425009", "AA74432303",  "AA74433748", "AA74434065", "AA74435697", "AA74437096",  "AA74440384", "AA74442937", "AA74444104", "AA74450790"]
deconf_cs = flight_plan[flight_plan['flightData.flightId.id'].isin(deconf_id)]["flightData.flightId.keys.aircraftId"].values.tolist()

neighbour_id = ["AA74416692", "AA74435999", "AA74457745",]
neighbour_cs = flight_plan[flight_plan['flightData.flightId.id'].isin(neighbour_id)]["flightData.flightId.keys.aircraftId"].values.tolist() + ["AIC129", "BEL5MQ", "ICE520", "ETD918", "QTR64J", "LHX2500", "KLM281"]

# %%
deconf_coms = callsigns_coms.query(f"callsign.isin({deconf_cs})")
deconf_coms.to_csv("deconf_coms.csv")

# %%
deconf_coms.query("callsign == 'RYR6NJ'")
# Out:
#      callsign                 timestamp  \
# 2270   RYR6NJ 2025-08-25 09:47:35+00:00
# 2570   RYR6NJ 2025-08-25 09:53:17+00:00
# 2571   RYR6NJ 2025-08-25 09:53:21+00:00
#
#                                                sentence  \
# 2270  good day ryan air six november juliett flight ...
# 2570  good day ryan air six november juliett flight ...
# 2571   ryan air six november juliett hello direct pepik
#
#                            detected  score  matched
# 2270  ryan air six november juliett    1.0     True
# 2570  ryan air six november juliett    1.0     True
# 2571  ryan air six november juliett    1.0     True

# %%
callsigns_coms.query("callsign == 'NSZ4MF'")
# Out:
#      callsign                 timestamp  \
# 6184   NSZ4MF 2025-08-25 20:25:08+00:00
# 6344   NSZ4MF 2025-08-25 20:16:06+00:00
#
#                                                sentence  \
# 6184  rednose four mike foxtrot reduce to speed back...
# 6344                                            foxtrot
#
#                        detected  score  matched
# 6184  rednose four mike foxtrot   1.00     True
# 6344                    foxtrot   0.72     True

# %%
transcripts
# Out:
# [[(datetime.datetime(2025, 8, 25, 0, 0, 6, tzinfo=datetime.timezone.utc),
#    'two two'),
#   (datetime.datetime(2025, 8, 25, 0, 0, 15, tzinfo=datetime.timezone.utc),
#    'two five'),
#   (datetime.datetime(2025, 8, 25, 0, 0, 19, tzinfo=datetime.timezone.utc),
#    'three five'),
#   (datetime.datetime(2025, 8, 25, 0, 0, 21, tzinfo=datetime.timezone.utc),
#    'lufthansa'),
#   (datetime.datetime(2025, 8, 25, 0, 0, 27, tzinfo=datetime.timezone.utc),
#    'navigator six alfa hotel papa three six two line up channex six alfa hotel identified'),
#   (datetime.datetime(2025, 8, 25, 0, 1, 8, tzinfo=datetime.timezone.utc),
#    'three three'),
#   (datetime.datetime(2025, 8, 25, 0, 1, 19, tzinfo=datetime.timezone.utc),
#    'foxtrot'),
#   (datetime.datetime(2025, 8, 25, 0, 2, 33, tzinfo=datetime.timezone.utc),
#    'three five'),
#   (datetime.datetime(2025, 8, 25, 0, 2, 58, tzinfo=datetime.timezone.utc),
#    'five five'),
#   (datetime.datetime(2025, 8, 25, 0, 3, 21, tzinfo=datetime.timezone.utc),
#    'three five'),
#   (datetime.datetime(2025, 8, 25, 0, 3, 37, tzinfo=datetime.timezone.utc),
#    'three five zero'),
#   (datetime.datetime(2025, 8, 25, 0, 3, 54, tzinfo=datetime.timezone.utc),
#    'three eight zero'),
#   (datetime.datetime(2025, 8, 25, 0, 4, 13, tzinfo=datetime.timezone.utc),
#    'five five zero'),
#   (datetime.datetime(2025, 8, 25, 0, 4, 26, tzinfo=datetime.timezone.utc),
#    'oscar kilo yankee level three eight zero inbound luna'),
#   (datetime.datetime(2025, 8, 25, 0, 4, 33, tzinfo=datetime.timezone.utc),
#    'channex six romeo yankee identified'),
#   (datetime.datetime(2025, 8, 25, 0, 4, 49, tzinfo=datetime.timezone.utc),
#    'three three'),
#   (datetime.datetime(2025, 8, 25, 0, 6, 11, tzinfo=datetime.timezone.utc),
#    've'),
#   (datetime.datetime(2025, 8, 25, 0, 7, 4, tzinfo=datetime.timezone.utc),
#    'praha second level vietnam one two good evening three three zero inbound to zucca'),
#   (datetime.datetime(2025, 8, 25, 0, 7, 11, tzinfo=datetime.timezone.utc),
#    'b air line seven one two identified'),
#   (datetime.datetime(2025, 8, 25, 0, 10, 16, tzinfo=datetime.timezone.utc),
#    'runway seven quebec foxtrot ready to check'),
#   (datetime.datetime(2025, 8, 25, 0, 10, 18, tzinfo=datetime.timezone.utc),
#    'ryan air seven quebec foxtrot reduce five and after about two thousand or more correction speed two one two five and you can you can make it direct to it darcy thank you it is clear nine seven quebec foxtrot'),
#   (datetime.datetime(2025, 8, 25, 0, 10, 30, tzinfo=datetime.timezone.utc),
#    'evening my straight to channex one one kilo echo flight level three six zero romeo channex one one kilo echo identified direct to odnem'),
#   (datetime.datetime(2025, 8, 25, 0, 10, 39, tzinfo=datetime.timezone.utc),
#    'thanks to hotel opera climbing four months later'),
#   (datetime.datetime(2025, 8, 25, 0, 12, 43, tzinfo=datetime.timezone.utc),
#    'northshuttel four kilo victor flight level three eight zero abrax'),
#   (datetime.datetime(2025, 8, 25, 0, 12, 50, tzinfo=datetime.timezone.utc),
#    'channex four kilo victor identified direct to op ed'),
#   (datetime.datetime(2025, 8, 25, 0, 12, 54, tzinfo=datetime.timezone.utc),
#    'direct rapet channex four kilo victor'),
#   (datetime.datetime(2025, 8, 25, 0, 14, 15, tzinfo=datetime.timezone.utc),
#    'praha hello channex'),
#   (datetime.datetime(2025, 8, 25, 0, 14, 20, tzinfo=datetime.timezone.utc),
#    'channex one three charlie kilo maintaining flight level three eight zero'),
#   (datetime.datetime(2025, 8, 25, 0, 14, 23, tzinfo=datetime.timezone.utc),
#    'channex one three charlie sierra identified'),
#   (datetime.datetime(2025, 8, 25, 0, 14, 54, tzinfo=datetime.timezone.utc),
#    'five five'),
#   (datetime.datetime(2025, 8, 25, 0, 15, 7, tzinfo=datetime.timezone.utc),
#    'five five'),
#   (datetime.datetime(2025, 8, 25, 0, 15, 13, tzinfo=datetime.timezone.utc),
#    've'),
#   (datetime.datetime(2025, 8, 25, 0, 15, 13, tzinfo=datetime.timezone.utc),
#    'affirm'),
#   (datetime.datetime(2025, 8, 25, 0, 15, 25, tzinfo=datetime.timezone.utc),
#    'three five zero'),
#   (datetime.datetime(2025, 8, 25, 0, 15, 40, tzinfo=datetime.timezone.utc),
#    'three five'),
#   (datetime.datetime(2025, 8, 25, 0, 15, 59, tzinfo=datetime.timezone.utc),
#    've'),
#   (datetime.datetime(2025, 8, 25, 0, 16, 5, tzinfo=datetime.timezone.utc),
#    'csa eight five'),
#   (datetime.datetime(2025, 8, 25, 0, 16, 16, tzinfo=datetime.timezone.utc),
#    'five five five'),
#   (datetime.datetime(2025, 8, 25, 0, 16, 32, tzinfo=datetime.timezone.utc),
#    'five whiskey'),
#   (datetime.datetime(2025, 8, 25, 0, 17, 13, tzinfo=datetime.timezone.utc),
#    'three five nine'),
#   (datetime.datetime(2025, 8, 25, 0, 17, 39, tzinfo=datetime.timezone.utc),
#    'foxtrot'),
#   (datetime.datetime(2025, 8, 25, 0, 17, 44, tzinfo=datetime.timezone.utc),
#    'six three'),
#   (datetime.datetime(2025, 8, 25, 0, 17, 49, tzinfo=datetime.timezone.utc),
#    'five'),
#   (datetime.datetime(2025, 8, 25, 0, 17, 58, tzinfo=datetime.timezone.utc),
#    'three five zero'),
#   (datetime.datetime(2025, 8, 25, 0, 18, 37, tzinfo=datetime.timezone.utc),
#    've'),
#   (datetime.datetime(2025, 8, 25, 0, 18, 47, tzinfo=datetime.timezone.utc),
#    'praha good evening channex one seven zero two flight level two six zero gosselt channex one seven zero two identified'),
#   (datetime.datetime(2025, 8, 25, 0, 19, 37, tzinfo=datetime.timezone.utc),
#    'three three'),
#   (datetime.datetime(2025, 8, 25, 0, 20, 23, tzinfo=datetime.timezone.utc),
#    'three five'),
#   (datetime.datetime(2025, 8, 25, 0, 21, 26, tzinfo=datetime.timezone.utc),
#    'master good evening to china xray papa quebec flight level three eight zero kolad'),
#   (datetime.datetime(2025, 8, 25, 0, 21, 34, tzinfo=datetime.timezone.utc),
#    'channex four three victor quebec identified'),
#   (datetime.datetime(2025, 8, 25, 0, 21, 47, tzinfo=datetime.timezone.utc),
#    'two five'),
#   (datetime.datetime(2025, 8, 25, 0, 21, 58, tzinfo=datetime.timezone.utc),
#    'three five'),
#   (datetime.datetime(2025, 8, 25, 0, 24, 53, tzinfo=datetime.timezone.utc),
#    'ok'),
#   (datetime.datetime(2025, 8, 25, 0, 26, 57, tzinfo=datetime.timezone.utc),
#    'three five zero'),
#   (datetime.datetime(2025, 8, 25, 0, 27, 53, tzinfo=datetime.timezone.utc),
#    'two five zero'),
#   (datetime.datetime(2025, 8, 25, 0, 30, 4, tzinfo=datetime.timezone.utc),
#    'two'),
#   (datetime.datetime(2025, 8, 25, 0, 31, 33, tzinfo=datetime.timezone.utc),
#    'navigator one eight eight level three three zero'),
#   (datetime.datetime(2025, 8, 25, 0, 31, 40, tzinfo=datetime.timezone.utc),
#    'air india one eight eight identified direct to marem'),
#   (datetime.datetime(2025, 8, 25, 0, 31, 46, tzinfo=datetime.timezone.utc),
#    'proceed direct marem air india one eight eight'),
#   (datetime.datetime(2025, 8, 25, 0, 34, 30, tzinfo=datetime.timezone.utc),
#    'radar good morning izrael seven five one one seven zero climbing two eight zero izrael seven five one identified and is two eight zero the requested level'),
#   (datetime.datetime(2025, 8, 25, 0, 34, 41, tzinfo=datetime.timezone.utc),
#    'three five'),
#   (datetime.datetime(2025, 8, 25, 0, 34, 43, tzinfo=datetime.timezone.utc),
#    'stand bye delta'),
#   (datetime.datetime(2025, 8, 25, 0, 34, 52, tzinfo=datetime.timezone.utc),
#    'euro trans flight level three six zero alfa seven five one'),
#   (datetime.datetime(2025, 8, 25, 0, 34, 56, tzinfo=datetime.timezone.utc),
#    'roger continue climb flight level three six zero'),
#   (datetime.datetime(2025, 8, 25, 0, 34, 59, tzinfo=datetime.timezone.utc),
#    'thank you flight level three six zero izrael seven five one'),
#   (datetime.datetime(2025, 8, 25, 0, 35, 29, tzinfo=datetime.timezone.utc),
#    'three zero'),
#   (datetime.datetime(2025, 8, 25, 0, 35, 53, tzinfo=datetime.timezone.utc),
#    'five five'),
#   (datetime.datetime(2025, 8, 25, 0, 35, 56, tzinfo=datetime.timezone.utc),
#    'affirm'),
#   (datetime.datetime(2025, 8, 25, 0, 37, tzinfo=datetime.timezone.utc), 've'),
#   (datetime.datetime(2025, 8, 25, 0, 37, 2, tzinfo=datetime.timezone.utc),
#    'affirmative'),
#   (datetime.datetime(2025, 8, 25, 0, 37, 22, tzinfo=datetime.timezone.utc),
#    'marsa good morning qnh is four six uniform november three eight zero to narka'),
#   (datetime.datetime(2025, 8, 25, 0, 37, 26, tzinfo=datetime.timezone.utc),
#    'channex four six uniform good bye for the ride identified'),
#   (datetime.datetime(2025, 8, 25, 0, 38, 5, tzinfo=datetime.timezone.utc),
#    'five six'),
#   (datetime.datetime(2025, 8, 25, 0, 39, 13, tzinfo=datetime.timezone.utc),
#    'masi good evening sky travel two five eight flight level three nine zero inbound voz'),
#   (datetime.datetime(2025, 8, 25, 0, 39, 18, tzinfo=datetime.timezone.utc),
#    'sky travel two five eight identified continue'),
#   (datetime.datetime(2025, 8, 25, 0, 39, 30, tzinfo=datetime.timezone.utc),
#    'three zero'),
#   (datetime.datetime(2025, 8, 25, 0, 39, 31, tzinfo=datetime.timezone.utc),
#    'radar good evening sky travel two five two flight level three seven zero inbound to arvek'),
#   (datetime.datetime(2025, 8, 25, 0, 39, 36, tzinfo=datetime.timezone.utc),
#    'sky travel two five two nine descend direct to omelo'),
#   (datetime.datetime(2025, 8, 25, 0, 39, 40, tzinfo=datetime.timezone.utc),
#    'direct romeo oscar lufthansa five two'),
#   (datetime.datetime(2025, 8, 25, 0, 39, 43, tzinfo=datetime.timezone.utc),
#    'roger and you can make it new squawk is one thousand'),
#   (datetime.datetime(2025, 8, 25, 0, 39, 47, tzinfo=datetime.timezone.utc),
#    'squawk one five two zero two five two'),
#   (datetime.datetime(2025, 8, 25, 0, 41, 45, tzinfo=datetime.timezone.utc),
#    'praha good day german air four six four seven flight level four three zero inbound patka'),
#   (datetime.datetime(2025, 8, 25, 0, 41, 51, tzinfo=datetime.timezone.utc),
#    'german air force six one seven identified continue'),
#   (datetime.datetime(2025, 8, 25, 0, 41, 56, tzinfo=datetime.timezone.utc),
#    'continue german air four six one bravo'),
#   (datetime.datetime(2025, 8, 25, 0, 42, 45, tzinfo=datetime.timezone.utc),
#    'three'),
#   (datetime.datetime(2025, 8, 25, 0, 44, 15, tzinfo=datetime.timezone.utc),
#    'hotel bravo hello the wizz air three xray xray flight level three six zero direct to oscar wizz air three xray xray identified'),
#   (datetime.datetime(2025, 8, 25, 0, 44, 41, tzinfo=datetime.timezone.utc),
#    'three five zero'),
#   (datetime.datetime(2025, 8, 25, 0, 44, 43, tzinfo=datetime.timezone.utc),
#    'nine'),
#   (datetime.datetime(2025, 8, 25, 0, 44, 55, tzinfo=datetime.timezone.utc),
#    'radar'),
#   (datetime.datetime(2025, 8, 25, 0, 46, 11, tzinfo=datetime.timezone.utc),
#    'three five'),
#   (datetime.datetime(2025, 8, 25, 0, 49, 51, tzinfo=datetime.timezone.utc),
#    'sky travel two five two can you lock on to the csa dia speed please echo delta yankee yankee'),
#   (datetime.datetime(2025, 8, 25, 0, 50, tzinfo=datetime.timezone.utc),
#    'roger oscar delta two'),
#   (datetime.datetime(2025, 8, 25, 0, 50, 10, tzinfo=datetime.timezone.utc),
#    'german air force six one seven direct to november victor oscar'),
#   (datetime.datetime(2025, 8, 25, 0, 50, 14, tzinfo=datetime.timezone.utc),
#    'departure lomli thanks a lot scandinavian air force six one seven'),
#   (datetime.datetime(2025, 8, 25, 0, 50, 24, tzinfo=datetime.timezone.utc),
#    'and german air force six one seven descend flight level two six zero'),
#   (datetime.datetime(2025, 8, 25, 0, 50, 29, tzinfo=datetime.timezone.utc),
#    'descend flight level two six zero german air four six one seven'),
#   (datetime.datetime(2025, 8, 25, 0, 50, 32, tzinfo=datetime.timezone.utc),
#    'can you give me two thousand feet per minute untill passing level three eight zero please'),
#   (datetime.datetime(2025, 8, 25, 0, 50, 38, tzinfo=datetime.timezone.utc),
#    'two thousand one passing three eight zero german air four six one seven'),
#   (datetime.datetime(2025, 8, 25, 0, 50, 44, tzinfo=datetime.timezone.utc),
#    'navigator two mike golf channex nine four bravo with november maintaining level three eight zero'),
#   (datetime.datetime(2025, 8, 25, 0, 50, 50, tzinfo=datetime.timezone.utc),
#    'channex nine four bravo november right over sight'),
#   (datetime.datetime(2025, 8, 25, 0, 50, 54, tzinfo=datetime.timezone.utc),
#    'five six sierra united nine one flight level three four zero united nine one identified'),
#   (datetime.datetime(2025, 8, 25, 0, 51, 2, tzinfo=datetime.timezone.utc),
#    'good morning good night wizz air eight seven lima romeo flight level three five zero inbound to dix wizz air eight seven lima romeo identified'),
#   (datetime.datetime(2025, 8, 25, 0, 51, 27, tzinfo=datetime.timezone.utc),
#    'five'),
#   (datetime.datetime(2025, 8, 25, 0, 51, 28, tzinfo=datetime.timezone.utc),
#    'three five'),
#   (datetime.datetime(2025, 8, 25, 0, 51, 32, tzinfo=datetime.timezone.utc),
#    'channex four six uniform november request descend'),
#   (datetime.datetime(2025, 8, 25, 0, 51, 36, tzinfo=datetime.timezone.utc),
#    'channex four six uniform november for that contact ruzyne one two eight decimal one six zero'),
#   (datetime.datetime(2025, 8, 25, 0, 51, 42, tzinfo=datetime.timezone.utc),
#    'hotel one six zero turning four six yes on the downwind good day'),
#   (datetime.datetime(2025, 8, 25, 0, 57, 22, tzinfo=datetime.timezone.utc),
#    'air india one eight eight nine'),
#   (datetime.datetime(2025, 8, 25, 0, 57, 35, tzinfo=datetime.timezone.utc),
#    'wilco three xray xray radio check'),
#   (datetime.datetime(2025, 8, 25, 0, 57, 41, tzinfo=datetime.timezone.utc),
#    'yeah wizz air three xray xray go ahead'),
#   (datetime.datetime(2025, 8, 25, 0, 57, 43, tzinfo=datetime.timezone.utc),
#    'yeah just doing a radio check thank you'),
#   (datetime.datetime(2025, 8, 25, 0, 57, 46, tzinfo=datetime.timezone.utc),
#    'five five five letko three x three xray'),
#   (datetime.datetime(2025, 8, 25, 0, 57, 49, tzinfo=datetime.timezone.utc),
#    'air india one eight eight'),
#   (datetime.datetime(2025, 8, 25, 0, 58, 9, tzinfo=datetime.timezone.utc),
#    'alfa india charlie one eight eight five six'),
#   (datetime.datetime(2025, 8, 25, 0, 58, 41, tzinfo=datetime.timezone.utc),
#    'two five two')],
#  [(datetime.datetime(2025, 8, 25, 0, 7, 56, tzinfo=datetime.timezone.utc),
#    'two five'),
#   (datetime.datetime(2025, 8, 25, 0, 9, 6, tzinfo=datetime.timezone.utc),
#    'thank you'),
#   (datetime.datetime(2025, 8, 25, 0, 13, 4, tzinfo=datetime.timezone.utc),
#    'two seven'),
#   (datetime.datetime(2025, 8, 25, 0, 13, 26, tzinfo=datetime.timezone.utc),
#    'two five two'),
#   (datetime.datetime(2025, 8, 25, 0, 16, 56, tzinfo=datetime.timezone.utc),
#    'five'),
#   (datetime.datetime(2025, 8, 25, 0, 18, 7, tzinfo=datetime.timezone.utc),
#    'three five csa seven five six'),
#   (datetime.datetime(2025, 8, 25, 0, 18, 11, tzinfo=datetime.timezone.utc),
#    'three'),
#   (datetime.datetime(2025, 8, 25, 0, 18, 33, tzinfo=datetime.timezone.utc),
#    'three five'),
#   (datetime.datetime(2025, 8, 25, 0, 19, 1, tzinfo=datetime.timezone.utc),
#    'three five zero'),
#   (datetime.datetime(2025, 8, 25, 0, 33, 2, tzinfo=datetime.timezone.utc),
#    'continue approach'),
#   (datetime.datetime(2025, 8, 25, 0, 34, 27, tzinfo=datetime.timezone.utc),
#    'radar good morning izrael seven five one one seven zero climbing two eight zero'),
#   (datetime.datetime(2025, 8, 25, 0, 34, 43, tzinfo=datetime.timezone.utc),
#    'stand bye sober'),
#   (datetime.datetime(2025, 8, 25, 0, 34, 51, tzinfo=datetime.timezone.utc),
#    'three six zero alfa five one'),
#   (datetime.datetime(2025, 8, 25, 0, 34, 59, tzinfo=datetime.timezone.utc),
#    'thank you flight level three six zero alfa is alfa one'),
#   (datetime.datetime(2025, 8, 25, 0, 36, 12, tzinfo=datetime.timezone.utc),
#    'five two'),
#   (datetime.datetime(2025, 8, 25, 0, 36, 54, tzinfo=datetime.timezone.utc),
#    'three five'),
#   (datetime.datetime(2025, 8, 25, 0, 37, 38, tzinfo=datetime.timezone.utc),
#    'csa'),
#   (datetime.datetime(2025, 8, 25, 0, 38, 5, tzinfo=datetime.timezone.utc),
#    'three five'),
#   (datetime.datetime(2025, 8, 25, 0, 38, 47, tzinfo=datetime.timezone.utc),
#    'two five'),
#   (datetime.datetime(2025, 8, 25, 0, 38, 51, tzinfo=datetime.timezone.utc),
#    'two five'),
#   (datetime.datetime(2025, 8, 25, 0, 39, 52, tzinfo=datetime.timezone.utc),
#    'romeo'),
#   (datetime.datetime(2025, 8, 25, 0, 40, 57, tzinfo=datetime.timezone.utc),
#    'three five'),
#   (datetime.datetime(2025, 8, 25, 0, 43, 32, tzinfo=datetime.timezone.utc),
#    've'),
#   (datetime.datetime(2025, 8, 25, 0, 43, 35, tzinfo=datetime.timezone.utc),
#    'three five'),
#   (datetime.datetime(2025, 8, 25, 0, 43, 58, tzinfo=datetime.timezone.utc),
#    'six seven'),
#   (datetime.datetime(2025, 8, 25, 0, 44, 16, tzinfo=datetime.timezone.utc),
#    'three seven'),
#   (datetime.datetime(2025, 8, 25, 0, 45, 33, tzinfo=datetime.timezone.utc),
#    'three five'),
#   (datetime.datetime(2025, 8, 25, 0, 46, 2, tzinfo=datetime.timezone.utc),
#    'two'),
#   (datetime.datetime(2025, 8, 25, 0, 47, 34, tzinfo=datetime.timezone.utc),
#    'left heading one zero'),
#   (datetime.datetime(2025, 8, 25, 0, 48, 9, tzinfo=datetime.timezone.utc),
#    'nine'),
#   (datetime.datetime(2025, 8, 25, 0, 48, 34, tzinfo=datetime.timezone.utc),
#    'three five'),
#   (datetime.datetime(2025, 8, 25, 0, 49, 13, tzinfo=datetime.timezone.utc),
#    'three five'),
#   (datetime.datetime(2025, 8, 25, 0, 49, 29, tzinfo=datetime.timezone.utc),
#    'six five'),
#   (datetime.datetime(2025, 8, 25, 0, 49, 43, tzinfo=datetime.timezone.utc),
#    'three two five'),
#   (datetime.datetime(2025, 8, 25, 0, 50, 20, tzinfo=datetime.timezone.utc),
#    'two five'),
#   (datetime.datetime(2025, 8, 25, 0, 50, 22, tzinfo=datetime.timezone.utc),
#    'five five'),
#   (datetime.datetime(2025, 8, 25, 0, 50, 52, tzinfo=datetime.timezone.utc),
#    'three three'),
#   (datetime.datetime(2025, 8, 25, 0, 51, 37, tzinfo=datetime.timezone.utc),
#    'three three'),
#   (datetime.datetime(2025, 8, 25, 0, 52, 12, tzinfo=datetime.timezone.utc),
#    'three five'),
#   (datetime.datetime(2025, 8, 25, 0, 52, 30, tzinfo=datetime.timezone.utc),
#    'two three'),
#   (datetime.datetime(2025, 8, 25, 0, 52, 55, tzinfo=datetime.timezone.utc),
#    'romeo'),
#   (datetime.datetime(2025, 8, 25, 0, 53, 37, tzinfo=datetime.timezone.utc),
#    'three five'),
#   (datetime.datetime(2025, 8, 25, 0, 54, 47, tzinfo=datetime.timezone.utc),
#    'two five'),
#   (datetime.datetime(2025, 8, 25, 0, 56, 3, tzinfo=datetime.timezone.utc),
#    'three five'),
#   (datetime.datetime(2025, 8, 25, 0, 56, 5, tzinfo=datetime.timezone.utc),
#    'three five'),
#   (datetime.datetime(2025, 8, 25, 0, 56, 22, tzinfo=datetime.timezone.utc),
#    'five'),
#   (datetime.datetime(2025, 8, 25, 0, 59, 29, tzinfo=datetime.timezone.utc),
#    'csa seven'),
#   (datetime.datetime(2025, 8, 25, 0, 59, 55, tzinfo=datetime.timezone.utc),
#    'two five two')],
#  [(datetime.datetime(2025, 8, 25, 0, 0, 29, tzinfo=datetime.timezone.utc),
#    'nav check six alfa delta three six zero right now'),
#   (datetime.datetime(2025, 8, 25, 0, 10, 30, tzinfo=datetime.timezone.utc),
#    'evening czech channex one one kilo echo flight level three six zero bravo'),
#   (datetime.datetime(2025, 8, 25, 0, 10, 39, tzinfo=datetime.timezone.utc),
#    'thanks direct to oscar channex one one juliett vacate'),
#   (datetime.datetime(2025, 8, 25, 0, 18, 49, tzinfo=datetime.timezone.utc),
#    'good evening channex one seven zero two flight level three six zero g'),
#   (datetime.datetime(2025, 8, 25, 0, 44, 15, tzinfo=datetime.timezone.utc),
#    'marsa hello it s the wizz air three xray xray flight level three six zero direct nograte'),
#   (datetime.datetime(2025, 8, 25, 0, 57, 41, tzinfo=datetime.timezone.utc),
#    'yeah whiskey three xray xray go ahead'),
#   (datetime.datetime(2025, 8, 25, 0, 57, 45, tzinfo=datetime.timezone.utc),
#    'five five five wizz air three xray xray')],
#  [],
#  [(datetime.datetime(2025, 8, 25, 1, 1, 55, tzinfo=datetime.timezone.utc),
#    'three seven'),
#   (datetime.datetime(2025, 8, 25, 1, 2, 10, tzinfo=datetime.timezone.utc),
#    'three five'),
#   (datetime.datetime(2025, 8, 25, 1, 2, 13, tzinfo=datetime.timezone.utc),
#    'three five'),
#   (datetime.datetime(2025, 8, 25, 1, 3, 28, tzinfo=datetime.timezone.utc),
#    'cleared to land'),
#   (datetime.datetime(2025, 8, 25, 1, 3, 37, tzinfo=datetime.timezone.utc),
#    'parture good evening qnh five mike is approaching three six zero direct bavik'),
#   (datetime.datetime(2025, 8, 25, 1, 4, 39, tzinfo=datetime.timezone.utc),
#    'three five'),
#   (datetime.datetime(2025, 8, 25, 1, 5, 18, tzinfo=datetime.timezone.utc),
#    'csa'),
#   (datetime.datetime(2025, 8, 25, 1, 5, 58, tzinfo=datetime.timezone.utc),
#    'three three'),
#   (datetime.datetime(2025, 8, 25, 1, 6, 6, tzinfo=datetime.timezone.utc),
#    'three five alfa'),
#   (datetime.datetime(2025, 8, 25, 1, 6, 30, tzinfo=datetime.timezone.utc),
#    'three five'),
#   (datetime.datetime(2025, 8, 25, 1, 6, 37, tzinfo=datetime.timezone.utc),
#    'three one'),
#   (datetime.datetime(2025, 8, 25, 1, 7, 11, tzinfo=datetime.timezone.utc),
#    'three five'),
#   (datetime.datetime(2025, 8, 25, 1, 7, 13, tzinfo=datetime.timezone.utc),
#    'three five'),
#   (datetime.datetime(2025, 8, 25, 1, 7, 18, tzinfo=datetime.timezone.utc),
#    'three five'),
#   (datetime.datetime(2025, 8, 25, 1, 7, 19, tzinfo=datetime.timezone.utc),
#    'affirm'),
#   (datetime.datetime(2025, 8, 25, 1, 7, 26, tzinfo=datetime.timezone.utc),
#    'five'),
#   (datetime.datetime(2025, 8, 25, 1, 7, 45, tzinfo=datetime.timezone.utc),
#    'five five'),
#   (datetime.datetime(2025, 8, 25, 1, 8, tzinfo=datetime.timezone.utc), 'csa'),
#   (datetime.datetime(2025, 8, 25, 1, 8, 29, tzinfo=datetime.timezone.utc),
#    'three five'),
#   (datetime.datetime(2025, 8, 25, 1, 8, 36, tzinfo=datetime.timezone.utc),
#    'three five'),
#   (datetime.datetime(2025, 8, 25, 1, 8, 45, tzinfo=datetime.timezone.utc),
#    'seven'),
#   (datetime.datetime(2025, 8, 25, 1, 9, 40, tzinfo=datetime.timezone.utc),
#    'cross'),
#   (datetime.datetime(2025, 8, 25, 1, 9, 48, tzinfo=datetime.timezone.utc),
#    'nine'),
#   (datetime.datetime(2025, 8, 25, 1, 9, 55, tzinfo=datetime.timezone.utc),
#    'three five'),
#   (datetime.datetime(2025, 8, 25, 1, 10, 7, tzinfo=datetime.timezone.utc),
#    'three five descending'),
#   (datetime.datetime(2025, 8, 25, 1, 10, 9, tzinfo=datetime.timezone.utc),
#    'three five tango'),
#   (datetime.datetime(2025, 8, 25, 1, 10, 19, tzinfo=datetime.timezone.utc),
#    'ok'),
#   (datetime.datetime(2025, 8, 25, 1, 10, 28, tzinfo=datetime.timezone.utc),
#    'five'),
#   (datetime.datetime(2025, 8, 25, 1, 10, 48, tzinfo=datetime.timezone.utc),
#    'two seven'),
#   (datetime.datetime(2025, 8, 25, 1, 10, 51, tzinfo=datetime.timezone.utc),
#    'three five'),
#   (datetime.datetime(2025, 8, 25, 1, 11, 11, tzinfo=datetime.timezone.utc),
#    'thank you'),
#   (datetime.datetime(2025, 8, 25, 1, 11, 20, tzinfo=datetime.timezone.utc),
#    'five five'),
#   (datetime.datetime(2025, 8, 25, 1, 11, 28, tzinfo=datetime.timezone.utc),
#    'three five'),
#   (datetime.datetime(2025, 8, 25, 1, 12, 15, tzinfo=datetime.timezone.utc),
#    'praha radar good evening qnh one four mike flight level three six zero pepik'),
#   (datetime.datetime(2025, 8, 25, 1, 12, 33, tzinfo=datetime.timezone.utc),
#    'three five'),
#   (datetime.datetime(2025, 8, 25, 1, 12, 39, tzinfo=datetime.timezone.utc),
#    'three five'),
#   (datetime.datetime(2025, 8, 25, 1, 12, 52, tzinfo=datetime.timezone.utc),
#    'three five'),
#   (datetime.datetime(2025, 8, 25, 1, 12, 52, tzinfo=datetime.timezone.utc),
#    'two five'),
#   (datetime.datetime(2025, 8, 25, 1, 13, 25, tzinfo=datetime.timezone.utc),
#    'five'),
#   (datetime.datetime(2025, 8, 25, 1, 13, 41, tzinfo=datetime.timezone.utc),
#    'three six'),
#   (datetime.datetime(2025, 8, 25, 1, 14, 11, tzinfo=datetime.timezone.utc),
#    'good day'),
#   (datetime.datetime(2025, 8, 25, 1, 14, 14, tzinfo=datetime.timezone.utc),
#    'three five five'),
#   (datetime.datetime(2025, 8, 25, 1, 14, 28, tzinfo=datetime.timezone.utc),
#    'five'),
#   (datetime.datetime(2025, 8, 25, 1, 14, 42, tzinfo=datetime.timezone.utc),
#    'five five'),
#   (datetime.datetime(2025, 8, 25, 1, 15, 15, tzinfo=datetime.timezone.utc),
#    'three five'),
#   (datetime.datetime(2025, 8, 25, 1, 15, 32, tzinfo=datetime.timezone.utc),
#    'three five'),
#   (datetime.datetime(2025, 8, 25, 1, 15, 48, tzinfo=datetime.timezone.utc),
#    'ok'),
#   (datetime.datetime(2025, 8, 25, 1, 15, 52, tzinfo=datetime.timezone.utc),
#    'three five'),
#   (datetime.datetime(2025, 8, 25, 1, 15, 52, tzinfo=datetime.timezone.utc),
#    'three five'),
#   (datetime.datetime(2025, 8, 25, 1, 16, 3, tzinfo=datetime.timezone.utc),
#    'affirm'),
#   (datetime.datetime(2025, 8, 25, 1, 16, 16, tzinfo=datetime.timezone.utc),
#    'two seven'),
#   (datetime.datetime(2025, 8, 25, 1, 16, 33, tzinfo=datetime.timezone.utc),
#    'nine'),
#   (datetime.datetime(2025, 8, 25, 1, 16, 46, tzinfo=datetime.timezone.utc),
#    'three five five'),
#   (datetime.datetime(2025, 8, 25, 1, 17, 3, tzinfo=datetime.timezone.utc),
#    'three five'),
#   (datetime.datetime(2025, 8, 25, 1, 17, 6, tzinfo=datetime.timezone.utc),
#    'good bye'),
#   (datetime.datetime(2025, 8, 25, 1, 17, 23, tzinfo=datetime.timezone.utc),
#    'five five'),
#   (datetime.datetime(2025, 8, 25, 1, 17, 37, tzinfo=datetime.timezone.utc),
#    'three six zero'),
#   (datetime.datetime(2025, 8, 25, 1, 17, 43, tzinfo=datetime.timezone.utc),
#    'three five five'),
#   (datetime.datetime(2025, 8, 25, 1, 18, 21, tzinfo=datetime.timezone.utc),
#    'two five five'),
#   (datetime.datetime(2025, 8, 25, 1, 18, 46, tzinfo=datetime.timezone.utc),
#    'two five'),
#   (datetime.datetime(2025, 8, 25, 1, 19, 11, tzinfo=datetime.timezone.utc),
#    'three five'),
#   (datetime.datetime(2025, 8, 25, 1, 19, 12, tzinfo=datetime.timezone.utc),
#    'csa'),
#   (datetime.datetime(2025, 8, 25, 1, 19, 19, tzinfo=datetime.timezone.utc),
#    'three five'),
#   (datetime.datetime(2025, 8, 25, 1, 19, 36, tzinfo=datetime.timezone.utc),
#    'five six'),
#   (datetime.datetime(2025, 8, 25, 1, 19, 37, tzinfo=datetime.timezone.utc),
#    'affirm'),
#   (datetime.datetime(2025, 8, 25, 1, 19, 53, tzinfo=datetime.timezone.utc),
#    'three five'),
#   (datetime.datetime(2025, 8, 25, 1, 19, 55, tzinfo=datetime.timezone.utc),
#    'three three'),
#   (datetime.datetime(2025, 8, 25, 1, 20, 19, tzinfo=datetime.timezone.utc),
#    'three five'),
#   (datetime.datetime(2025, 8, 25, 1, 20, 26, tzinfo=datetime.timezone.utc),
#    'three five zero'),
#   (datetime.datetime(2025, 8, 25, 1, 20, 42, tzinfo=datetime.timezone.utc),
#    'two five five'),
#   (datetime.datetime(2025, 8, 25, 1, 21, 44, tzinfo=datetime.timezone.utc),
#    'three five'),
#   (datetime.datetime(2025, 8, 25, 1, 21, 52, tzinfo=datetime.timezone.utc),
#    'three five'),
#   (datetime.datetime(2025, 8, 25, 1, 21, 56, tzinfo=datetime.timezone.utc),
#    'five five'),
#   (datetime.datetime(2025, 8, 25, 1, 22, 12, tzinfo=datetime.timezone.utc),
#    'three five'),
#   (datetime.datetime(2025, 8, 25, 1, 22, 25, tzinfo=datetime.timezone.utc),
#    'three five'),
#   (datetime.datetime(2025, 8, 25, 1, 23, 6, tzinfo=datetime.timezone.utc),
#    'three five'),
#   (datetime.datetime(2025, 8, 25, 1, 23, 17, tzinfo=datetime.timezone.utc),
#    'sky travel six three one'),
#   (datetime.datetime(2025, 8, 25, 1, 23, 38, tzinfo=datetime.timezone.utc),
#    'two five'),
#   (datetime.datetime(2025, 8, 25, 1, 23, 50, tzinfo=datetime.timezone.utc),
#    'five zero'),
#   (datetime.datetime(2025, 8, 25, 1, 24, 22, tzinfo=datetime.timezone.utc),
#    'three five'),
#   (datetime.datetime(2025, 8, 25, 1, 24, 36, tzinfo=datetime.timezone.utc),
#    'three one'),
#   (datetime.datetime(2025, 8, 25, 1, 24, 44, tzinfo=datetime.timezone.utc),
#    'three five zero'),
#   (datetime.datetime(2025, 8, 25, 1, 25, 7, tzinfo=datetime.timezone.utc),
#    'three five'),
#   (datetime.datetime(2025, 8, 25, 1, 25, 17, tzinfo=datetime.timezone.utc),
#    'three three'),
#   (datetime.datetime(2025, 8, 25, 1, 25, 38, tzinfo=datetime.timezone.utc),
#    'romeo'),
#   (datetime.datetime(2025, 8, 25, 1, 25, 58, tzinfo=datetime.timezone.utc),
#    'three five'),
#   (datetime.datetime(2025, 8, 25, 1, 26, 18, tzinfo=datetime.timezone.utc),
#    'three five'),
#   (datetime.datetime(2025, 8, 25, 1, 26, 27, tzinfo=datetime.timezone.utc),
#    'three five'),
#   (datetime.datetime(2025, 8, 25, 1, 27, 21, tzinfo=datetime.timezone.utc),
#    'six zero'),
#   (datetime.datetime(2025, 8, 25, 1, 27, 26, tzinfo=datetime.timezone.utc),
#    'romeo golf'),
#   (datetime.datetime(2025, 8, 25, 1, 27, 33, tzinfo=datetime.timezone.utc),
#    'three five'),
#   (datetime.datetime(2025, 8, 25, 1, 27, 59, tzinfo=datetime.timezone.utc),
#    'three five'),
#   (datetime.datetime(2025, 8, 25, 1, 28, 13, tzinfo=datetime.timezone.utc),
#    'three five'),
#   (datetime.datetime(2025, 8, 25, 1, 28, 13, tzinfo=datetime.timezone.utc),
#    'three five'),
#   (datetime.datetime(2025, 8, 25, 1, 28, 35, tzinfo=datetime.timezone.utc),
#    'three five'),
#   (datetime.datetime(2025, 8, 25, 1, 29, 33, tzinfo=datetime.timezone.utc),
#    'three five'),
#   (datetime.datetime(2025, 8, 25, 1, 29, 38, tzinfo=datetime.timezone.utc),
#    'three one'),
#   (datetime.datetime(2025, 8, 25, 1, 29, 50, tzinfo=datetime.timezone.utc),
#    'affirm'),
#   (datetime.datetime(2025, 8, 25, 1, 29, 52, tzinfo=datetime.timezone.utc),
#    'three five'),
#   (datetime.datetime(2025, 8, 25, 1, 29, 55, tzinfo=datetime.timezone.utc),
#    'six papa'),
#   (datetime.datetime(2025, 8, 25, 1, 30, 6, tzinfo=datetime.timezone.utc),
#    'three five'),
#   (datetime.datetime(2025, 8, 25, 1, 30, 23, tzinfo=datetime.timezone.utc),
#    'three five'),
#   (datetime.datetime(2025, 8, 25, 1, 30, 38, tzinfo=datetime.timezone.utc),
#    'three fo'),
#   (datetime.datetime(2025, 8, 25, 1, 30, 43, tzinfo=datetime.timezone.utc),
#    'three five'),
#   (datetime.datetime(2025, 8, 25, 1, 31, 2, tzinfo=datetime.timezone.utc),
#    'five five'),
#   (datetime.datetime(2025, 8, 25, 1, 31, 9, tzinfo=datetime.timezone.utc),
#    'three five'),
#   (datetime.datetime(2025, 8, 25, 1, 31, 16, tzinfo=datetime.timezone.utc),
#    'six six zero'),
#   (datetime.datetime(2025, 8, 25, 1, 31, 40, tzinfo=datetime.timezone.utc),
#    'three five'),
#   (datetime.datetime(2025, 8, 25, 1, 31, 54, tzinfo=datetime.timezone.utc),
#    'three five'),
#   (datetime.datetime(2025, 8, 25, 1, 32, 2, tzinfo=datetime.timezone.utc),
#    'high speed'),
#   (datetime.datetime(2025, 8, 25, 1, 32, 5, tzinfo=datetime.timezone.utc),
#    'three five'),
#   (datetime.datetime(2025, 8, 25, 1, 32, 24, tzinfo=datetime.timezone.utc),
#    'three five'),
#   (datetime.datetime(2025, 8, 25, 1, 32, 28, tzinfo=datetime.timezone.utc),
#    'five'),
#   (datetime.datetime(2025, 8, 25, 1, 32, 46, tzinfo=datetime.timezone.utc),
#    'two five'),
#   (datetime.datetime(2025, 8, 25, 1, 32, 56, tzinfo=datetime.timezone.utc),
#    'three five'),
#   (datetime.datetime(2025, 8, 25, 1, 33, 16, tzinfo=datetime.timezone.utc),
#    'two zero'),
#   (datetime.datetime(2025, 8, 25, 1, 33, 29, tzinfo=datetime.timezone.utc),
#    'romeo'),
#   (datetime.datetime(2025, 8, 25, 1, 33, 35, tzinfo=datetime.timezone.utc),
#    'three five'),
#   (datetime.datetime(2025, 8, 25, 1, 33, 41, tzinfo=datetime.timezone.utc),
#    'three five'),
#   (datetime.datetime(2025, 8, 25, 1, 33, 57, tzinfo=datetime.timezone.utc),
#    'three five'),
#   (datetime.datetime(2025, 8, 25, 1, 34, 25, tzinfo=datetime.timezone.utc),
#    'three three'),
#   (datetime.datetime(2025, 8, 25, 1, 35, 3, tzinfo=datetime.timezone.utc),
#    'five six'),
#   (datetime.datetime(2025, 8, 25, 1, 35, 44, tzinfo=datetime.timezone.utc),
#    'three five'),
#   (datetime.datetime(2025, 8, 25, 1, 36, 35, tzinfo=datetime.timezone.utc),
#    'three zero'),
#   (datetime.datetime(2025, 8, 25, 1, 37, 20, tzinfo=datetime.timezone.utc),
#    'three five'),
#   (datetime.datetime(2025, 8, 25, 1, 37, 32, tzinfo=datetime.timezone.utc),
#    'affirm'),
#   (datetime.datetime(2025, 8, 25, 1, 37, 35, tzinfo=datetime.timezone.utc),
#    'three five'),
#   (datetime.datetime(2025, 8, 25, 1, 38, 8, tzinfo=datetime.timezone.utc),
#    'three five'),
#   (datetime.datetime(2025, 8, 25, 1, 38, 9, tzinfo=datetime.timezone.utc),
#    'three five'),
#   (datetime.datetime(2025, 8, 25, 1, 38, 22, tzinfo=datetime.timezone.utc),
#    'two three'),
#   (datetime.datetime(2025, 8, 25, 1, 38, 42, tzinfo=datetime.timezone.utc),
#    'three five'),
#   (datetime.datetime(2025, 8, 25, 1, 38, 54, tzinfo=datetime.timezone.utc),
#    'three zero'),
#   (datetime.datetime(2025, 8, 25, 1, 38, 56, tzinfo=datetime.timezone.utc),
#    'three five'),
#   (datetime.datetime(2025, 8, 25, 1, 39, 3, tzinfo=datetime.timezone.utc),
#    'six five'),
#   (datetime.datetime(2025, 8, 25, 1, 39, 8, tzinfo=datetime.timezone.utc),
#    'three five'),
#   (datetime.datetime(2025, 8, 25, 1, 39, 27, tzinfo=datetime.timezone.utc),
#    'five two'),
#   (datetime.datetime(2025, 8, 25, 1, 39, 33, tzinfo=datetime.timezone.utc),
#    'three five'),
#   (datetime.datetime(2025, 8, 25, 1, 39, 43, tzinfo=datetime.timezone.utc),
#    'romeo'),
#   (datetime.datetime(2025, 8, 25, 1, 40, 11, tzinfo=datetime.timezone.utc),
#    'nine six'),
#   (datetime.datetime(2025, 8, 25, 1, 40, 46, tzinfo=datetime.timezone.utc),
#    'three five'),
#   (datetime.datetime(2025, 8, 25, 1, 41, 36, tzinfo=datetime.timezone.utc),
#    'six five'),
#   (datetime.datetime(2025, 8, 25, 1, 41, 44, tzinfo=datetime.timezone.utc),
#    'two five'),
#   (datetime.datetime(2025, 8, 25, 1, 42, 2, tzinfo=datetime.timezone.utc),
#    'three five'),
#   (datetime.datetime(2025, 8, 25, 1, 42, 14, tzinfo=datetime.timezone.utc),
#    'three five'),
#   (datetime.datetime(2025, 8, 25, 1, 42, 36, tzinfo=datetime.timezone.utc),
#    'two seven zero'),
#   (datetime.datetime(2025, 8, 25, 1, 42, 37, tzinfo=datetime.timezone.utc),
#    'two five five'),
#   (datetime.datetime(2025, 8, 25, 1, 42, 38, tzinfo=datetime.timezone.utc),
#    'ok'),
#   (datetime.datetime(2025, 8, 25, 1, 42, 48, tzinfo=datetime.timezone.utc),
#    'three five'),
#   (datetime.datetime(2025, 8, 25, 1, 42, 49, tzinfo=datetime.timezone.utc),
#    'ok bye'),
#   (datetime.datetime(2025, 8, 25, 1, 43, 7, tzinfo=datetime.timezone.utc),
#    'three three'),
#   (datetime.datetime(2025, 8, 25, 1, 43, 19, tzinfo=datetime.timezone.utc),
#    'five five'),
#   (datetime.datetime(2025, 8, 25, 1, 43, 23, tzinfo=datetime.timezone.utc),
#    'three five'),
#   (datetime.datetime(2025, 8, 25, 1, 43, 48, tzinfo=datetime.timezone.utc),
#    'romeo'),
#   (datetime.datetime(2025, 8, 25, 1, 44, 5, tzinfo=datetime.timezone.utc),
#    'three five'),
#   (datetime.datetime(2025, 8, 25, 1, 45, 6, tzinfo=datetime.timezone.utc),
#    'three five'),
#   (datetime.datetime(2025, 8, 25, 1, 45, 37, tzinfo=datetime.timezone.utc),
#    'ok'),
#   (datetime.datetime(2025, 8, 25, 1, 45, 57, tzinfo=datetime.timezone.utc),
#    'three five'),
#   (datetime.datetime(2025, 8, 25, 1, 46, 16, tzinfo=datetime.timezone.utc),
#    'three five'),
#   (datetime.datetime(2025, 8, 25, 1, 46, 28, tzinfo=datetime.timezone.utc),
#    'three five'),
#   (datetime.datetime(2025, 8, 25, 1, 46, 36, tzinfo=datetime.timezone.utc),
#    'five five'),
#   (datetime.datetime(2025, 8, 25, 1, 46, 38, tzinfo=datetime.timezone.utc),
#    'romeo'),
#   (datetime.datetime(2025, 8, 25, 1, 46, 43, tzinfo=datetime.timezone.utc),
#    'good day'),
#   (datetime.datetime(2025, 8, 25, 1, 46, 46, tzinfo=datetime.timezone.utc),
#    'good bye'),
#   (datetime.datetime(2025, 8, 25, 1, 46, 59, tzinfo=datetime.timezone.utc),
#    'praha radar hello el al zero two seven heavy flight level three six zero'),
#   (datetime.datetime(2025, 8, 25, 1, 47, 10, tzinfo=datetime.timezone.utc),
#    'thank you'),
#   (datetime.datetime(2025, 8, 25, 1, 47, 13, tzinfo=datetime.timezone.utc),
#    'three five'),
#   (datetime.datetime(2025, 8, 25, 1, 47, 24, tzinfo=datetime.timezone.utc),
#    'good evening qnh six two zero flight level three six zero'),
#   (datetime.datetime(2025, 8, 25, 1, 49, 33, tzinfo=datetime.timezone.utc),
#    'three five zero'),
#   (datetime.datetime(2025, 8, 25, 1, 55, 13, tzinfo=datetime.timezone.utc),
#    'lufthansa six'),
#   (datetime.datetime(2025, 8, 25, 1, 56, 49, tzinfo=datetime.timezone.utc),
#    'two five'),
#   (datetime.datetime(2025, 8, 25, 1, 57, 50, tzinfo=datetime.timezone.utc),
#    've'),
#   (datetime.datetime(2025, 8, 25, 1, 57, 55, tzinfo=datetime.timezone.utc),
#    'two five'),
#   (datetime.datetime(2025, 8, 25, 1, 58, 1, tzinfo=datetime.timezone.utc),
#    'three five'),
#   (datetime.datetime(2025, 8, 25, 1, 58, 32, tzinfo=datetime.timezone.utc),
#    'two two'),
#   (datetime.datetime(2025, 8, 25, 1, 59, 5, tzinfo=datetime.timezone.utc),
#    'three five'),
#   (datetime.datetime(2025, 8, 25, 1, 59, 24, tzinfo=datetime.timezone.utc),
#    'three five'),
#   (datetime.datetime(2025, 8, 25, 1, 59, 44, tzinfo=datetime.timezone.utc),
#    'five five')],
#  [(datetime.datetime(2025, 8, 25, 1, 1, 51, tzinfo=datetime.timezone.utc),
#    'good bye'),
#   (datetime.datetime(2025, 8, 25, 1, 1, 53, tzinfo=datetime.timezone.utc),
#    'romeo'),
#   (datetime.datetime(2025, 8, 25, 1, 2, 1, tzinfo=datetime.timezone.utc),
#    'three five'),
#   (datetime.datetime(2025, 8, 25, 1, 2, 7, tzinfo=datetime.timezone.utc),
#    'navigator hello this is popol three eight two four reaching maintain flight level three four zero direct to lokka'),
#   (datetime.datetime(2025, 8, 25, 1, 2, 15, tzinfo=datetime.timezone.utc),
#    'good morning air portugal three eight four four stand at six five'),
#   (datetime.datetime(2025, 8, 25, 1, 2, 20, tzinfo=datetime.timezone.utc),
#    'thank you'),
#   (datetime.datetime(2025, 8, 25, 1, 2, 36, tzinfo=datetime.timezone.utc),
#    'five zero'),
#   (datetime.datetime(2025, 8, 25, 1, 2, 50, tzinfo=datetime.timezone.utc),
#    'two five'),
#   (datetime.datetime(2025, 8, 25, 1, 2, 52, tzinfo=datetime.timezone.utc),
#    'three five'),
#   (datetime.datetime(2025, 8, 25, 1, 3, 9, tzinfo=datetime.timezone.utc),
#    'three five'),
#   (datetime.datetime(2025, 8, 25, 1, 3, 36, tzinfo=datetime.timezone.utc),
#    'praha good evening qnh five mike is flight level three six zero direct bacik'),
#   (datetime.datetime(2025, 8, 25, 1, 3, 42, tzinfo=datetime.timezone.utc),
#    'good morning the five mike and then the five'),
#   (datetime.datetime(2025, 8, 25, 1, 3, 48, tzinfo=datetime.timezone.utc),
#    'three five'),
#   (datetime.datetime(2025, 8, 25, 1, 3, 59, tzinfo=datetime.timezone.utc),
#    'two five'),
#   (datetime.datetime(2025, 8, 25, 1, 4, 4, tzinfo=datetime.timezone.utc),
#    'five five'),
#   (datetime.datetime(2025, 8, 25, 1, 4, 8, tzinfo=datetime.timezone.utc),
#    'three five'),
#   (datetime.datetime(2025, 8, 25, 1, 7, 59, tzinfo=datetime.timezone.utc),
#    'five five six'),
#   (datetime.datetime(2025, 8, 25, 1, 9, tzinfo=datetime.timezone.utc),
#    'affirm'),
#   (datetime.datetime(2025, 8, 25, 1, 9, 18, tzinfo=datetime.timezone.utc),
#    'three one'),
#   (datetime.datetime(2025, 8, 25, 1, 9, 40, tzinfo=datetime.timezone.utc),
#    'continue approach'),
#   (datetime.datetime(2025, 8, 25, 1, 10, 14, tzinfo=datetime.timezone.utc),
#    'three five'),
#   (datetime.datetime(2025, 8, 25, 1, 11, 45, tzinfo=datetime.timezone.utc),
#    'three zero'),
#   (datetime.datetime(2025, 8, 25, 1, 12, 11, tzinfo=datetime.timezone.utc),
#    'navigator three six zero'),
#   (datetime.datetime(2025, 8, 25, 1, 12, 23, tzinfo=datetime.timezone.utc),
#    'good morning kilo charlie channex one four mike and this is thai'),
#   (datetime.datetime(2025, 8, 25, 1, 12, 34, tzinfo=datetime.timezone.utc),
#    'three five'),
#   (datetime.datetime(2025, 8, 25, 1, 12, 43, tzinfo=datetime.timezone.utc),
#    'affirm'),
#   (datetime.datetime(2025, 8, 25, 1, 13, 31, tzinfo=datetime.timezone.utc),
#    'three zero'),
#   (datetime.datetime(2025, 8, 25, 1, 13, 47, tzinfo=datetime.timezone.utc),
#    'six five'),
#   (datetime.datetime(2025, 8, 25, 1, 13, 48, tzinfo=datetime.timezone.utc),
#    'three five'),
#   (datetime.datetime(2025, 8, 25, 1, 14, 14, tzinfo=datetime.timezone.utc),
#    'three five'),
#   (datetime.datetime(2025, 8, 25, 1, 17, 26, tzinfo=datetime.timezone.utc),
#    'master cimber good morning turkish five five one flight level three two zero'),
#   (datetime.datetime(2025, 8, 25, 1, 17, 49, tzinfo=datetime.timezone.utc),
#    'good morning turkish six five five one ready to mike'),
#   (datetime.datetime(2025, 8, 25, 1, 18, 34, tzinfo=datetime.timezone.utc),
#    'air france one three eight four four is ready for descend'),
#   (datetime.datetime(2025, 8, 25, 1, 18, 37, tzinfo=datetime.timezone.utc),
#    'air france three eight four four initially climb level one seven zero'),
#   (datetime.datetime(2025, 8, 25, 1, 18, 42, tzinfo=datetime.timezone.utc),
#    'descend flight level one seven zero for foxtrot three eight four four'),
#   (datetime.datetime(2025, 8, 25, 1, 19, tzinfo=datetime.timezone.utc),
#    'ryan air six seven jet hotel yankee flight level three six zero direct to renek hello good morning seven hotel yankee and that is ryan air six seven'),
#   (datetime.datetime(2025, 8, 25, 1, 19, 10, tzinfo=datetime.timezone.utc),
#    'three five'),
#   (datetime.datetime(2025, 8, 25, 1, 19, 10, tzinfo=datetime.timezone.utc),
#    'affirm'),
#   (datetime.datetime(2025, 8, 25, 1, 19, 22, tzinfo=datetime.timezone.utc),
#    'two five'),
#   (datetime.datetime(2025, 8, 25, 1, 20, 56, tzinfo=datetime.timezone.utc),
#    'three eight'),
#   (datetime.datetime(2025, 8, 25, 1, 21, 18, tzinfo=datetime.timezone.utc),
#    'hotel hotel yankee austrian three eight four four contact gopin one three three decimal one five five good bye'),
#   (datetime.datetime(2025, 8, 25, 1, 21, 29, tzinfo=datetime.timezone.utc),
#    'one three three one five five wizz air four romeo alfa four bye bye'),
#   (datetime.datetime(2025, 8, 25, 1, 21, 52, tzinfo=datetime.timezone.utc),
#    've'),
#   (datetime.datetime(2025, 8, 25, 1, 22, 3, tzinfo=datetime.timezone.utc),
#    'three five'),
#   (datetime.datetime(2025, 8, 25, 1, 22, 28, tzinfo=datetime.timezone.utc),
#    'three five'),
#   (datetime.datetime(2025, 8, 25, 1, 23, 20, tzinfo=datetime.timezone.utc),
#    'sydney tower'),
#   (datetime.datetime(2025, 8, 25, 1, 23, 25, tzinfo=datetime.timezone.utc),
#    'three five'),
#   (datetime.datetime(2025, 8, 25, 1, 23, 34, tzinfo=datetime.timezone.utc),
#    'praha radar'),
#   (datetime.datetime(2025, 8, 25, 1, 23, 39, tzinfo=datetime.timezone.utc),
#    'three bravo hotel flight level four hundred line up'),
#   (datetime.datetime(2025, 8, 25, 1, 23, 43, tzinfo=datetime.timezone.utc),
#    'hello good morning three bravo hotel at any time'),
#   (datetime.datetime(2025, 8, 25, 1, 23, 49, tzinfo=datetime.timezone.utc),
#    'five'),
#   (datetime.datetime(2025, 8, 25, 1, 23, 59, tzinfo=datetime.timezone.utc),
#    'praha radar good morning turkish one eight one heavy flight level three four zero good morning turkish one eight one'),
#   (datetime.datetime(2025, 8, 25, 1, 24, 12, tzinfo=datetime.timezone.utc),
#    'three five zero'),
#   (datetime.datetime(2025, 8, 25, 1, 24, 23, tzinfo=datetime.timezone.utc),
#    'three five'),
#   (datetime.datetime(2025, 8, 25, 1, 27, 32, tzinfo=datetime.timezone.utc),
#    'two five'),
#   (datetime.datetime(2025, 8, 25, 1, 27, 47, tzinfo=datetime.timezone.utc),
#    'three five zero'),
#   (datetime.datetime(2025, 8, 25, 1, 27, 49, tzinfo=datetime.timezone.utc),
#    'three five'),
#   (datetime.datetime(2025, 8, 25, 1, 28, 47, tzinfo=datetime.timezone.utc),
#    'praha radar'),
#   (datetime.datetime(2025, 8, 25, 1, 29, 5, tzinfo=datetime.timezone.utc),
#    'three five'),
#   (datetime.datetime(2025, 8, 25, 1, 29, 17, tzinfo=datetime.timezone.utc),
#    'three five'),
#   (datetime.datetime(2025, 8, 25, 1, 29, 29, tzinfo=datetime.timezone.utc),
#    'csa'),
#   (datetime.datetime(2025, 8, 25, 1, 29, 46, tzinfo=datetime.timezone.utc),
#    'three zero'),
#   (datetime.datetime(2025, 8, 25, 1, 30, 1, tzinfo=datetime.timezone.utc),
#    'three five'),
#   (datetime.datetime(2025, 8, 25, 1, 31, 10, tzinfo=datetime.timezone.utc),
#    'three five'),
#   (datetime.datetime(2025, 8, 25, 1, 31, 27, tzinfo=datetime.timezone.utc),
#    'two five five'),
#   (datetime.datetime(2025, 8, 25, 1, 31, 29, tzinfo=datetime.timezone.utc),
#    'air france hello trans avia eight hotel victor flight level three eight zero'),
#   (datetime.datetime(2025, 8, 25, 1, 31, 34, tzinfo=datetime.timezone.utc),
#    'good morning jet eight hotel victor five hundred five'),
#   (datetime.datetime(2025, 8, 25, 1, 34, 35, tzinfo=datetime.timezone.utc),
#    'three five'),
#   (datetime.datetime(2025, 8, 25, 1, 35, 23, tzinfo=datetime.timezone.utc),
#    'three five'),
#   (datetime.datetime(2025, 8, 25, 1, 35, 43, tzinfo=datetime.timezone.utc),
#    'six five'),
#   (datetime.datetime(2025, 8, 25, 1, 35, 44, tzinfo=datetime.timezone.utc),
#    'romeo'),
#   (datetime.datetime(2025, 8, 25, 1, 36, 53, tzinfo=datetime.timezone.utc),
#    'six zero'),
#   (datetime.datetime(2025, 8, 25, 1, 37, 9, tzinfo=datetime.timezone.utc),
#    'three five'),
#   (datetime.datetime(2025, 8, 25, 1, 37, 52, tzinfo=datetime.timezone.utc),
#    'three five'),
#   (datetime.datetime(2025, 8, 25, 1, 38, 26, tzinfo=datetime.timezone.utc),
#    'three five'),
#   (datetime.datetime(2025, 8, 25, 1, 39, 15, tzinfo=datetime.timezone.utc),
#    'three eight'),
#   (datetime.datetime(2025, 8, 25, 1, 40, 16, tzinfo=datetime.timezone.utc),
#    'three five'),
#   (datetime.datetime(2025, 8, 25, 1, 40, 18, tzinfo=datetime.timezone.utc),
#    'three three'),
#   (datetime.datetime(2025, 8, 25, 1, 40, 20, tzinfo=datetime.timezone.utc),
#    'bastar good day turkish one four three heavy flight level three two zero'),
#   (datetime.datetime(2025, 8, 25, 1, 40, 26, tzinfo=datetime.timezone.utc),
#    'hello good morning vietnam alfa sierra identified'),
#   (datetime.datetime(2025, 8, 25, 1, 40, 29, tzinfo=datetime.timezone.utc),
#    'roger'),
#   (datetime.datetime(2025, 8, 25, 1, 40, 31, tzinfo=datetime.timezone.utc),
#    'turkish six five five one contact qantas one two one three two five good bye'),
#   (datetime.datetime(2025, 8, 25, 1, 40, 38, tzinfo=datetime.timezone.utc),
#    'one two one three two five good bye turkish six five five one'),
#   (datetime.datetime(2025, 8, 25, 1, 40, 52, tzinfo=datetime.timezone.utc),
#    'radar good morning to lufthansa two nine six zero level three eight zero pepik'),
#   (datetime.datetime(2025, 8, 25, 1, 40, 57, tzinfo=datetime.timezone.utc),
#    'direct to poltman two nine six zero when identified'),
#   (datetime.datetime(2025, 8, 25, 1, 41, 10, tzinfo=datetime.timezone.utc),
#    'three five'),
#   (datetime.datetime(2025, 8, 25, 1, 41, 11, tzinfo=datetime.timezone.utc),
#    'affirm'),
#   (datetime.datetime(2025, 8, 25, 1, 41, 13, tzinfo=datetime.timezone.utc),
#    'three'),
#   (datetime.datetime(2025, 8, 25, 1, 41, 16, tzinfo=datetime.timezone.utc),
#    'affirm'),
#   (datetime.datetime(2025, 8, 25, 1, 41, 35, tzinfo=datetime.timezone.utc),
#    'csa'),
#   (datetime.datetime(2025, 8, 25, 1, 41, 58, tzinfo=datetime.timezone.utc),
#    'three five'),
#   (datetime.datetime(2025, 8, 25, 1, 43, 32, tzinfo=datetime.timezone.utc),
#    'navigator hello air france four nine five flight level three eight zero'),
#   (datetime.datetime(2025, 8, 25, 1, 43, 39, tzinfo=datetime.timezone.utc),
#    'good morning jet four nine five five nine five'),
#   (datetime.datetime(2025, 8, 25, 1, 44, 5, tzinfo=datetime.timezone.utc),
#    'five five'),
#   (datetime.datetime(2025, 8, 25, 1, 46, 31, tzinfo=datetime.timezone.utc),
#    'three five'),
#   (datetime.datetime(2025, 8, 25, 1, 47, tzinfo=datetime.timezone.utc),
#    'five'),
#   (datetime.datetime(2025, 8, 25, 1, 47, tzinfo=datetime.timezone.utc),
#    'praha radar hello el al zero two seven heavy flight level three six zero we are holding al al zero two seven and landing mike'),
#   (datetime.datetime(2025, 8, 25, 1, 47, 10, tzinfo=datetime.timezone.utc),
#    'thank you'),
#   (datetime.datetime(2025, 8, 25, 1, 47, 24, tzinfo=datetime.timezone.utc),
#    'good evening qnh six two zero flight level three six zero bernet hello qnh six two zero identified'),
#   (datetime.datetime(2025, 8, 25, 1, 47, 51, tzinfo=datetime.timezone.utc),
#    'three five'),
#   (datetime.datetime(2025, 8, 25, 1, 49, 46, tzinfo=datetime.timezone.utc),
#    'three three'),
#   (datetime.datetime(2025, 8, 25, 1, 49, 48, tzinfo=datetime.timezone.utc),
#    'good day'),
#   (datetime.datetime(2025, 8, 25, 1, 49, 55, tzinfo=datetime.timezone.utc),
#    'three five'),
#   (datetime.datetime(2025, 8, 25, 1, 50, 39, tzinfo=datetime.timezone.utc),
#    'three five'),
#   (datetime.datetime(2025, 8, 25, 1, 50, 41, tzinfo=datetime.timezone.utc),
#    'three five'),
#   (datetime.datetime(2025, 8, 25, 1, 50, 43, tzinfo=datetime.timezone.utc),
# ...
#   (datetime.datetime(2025, 8, 25, 23, 9, 21, tzinfo=datetime.timezone.utc),
#    'ryan air six four juliett alfa good day ryan air five'),
#   (datetime.datetime(2025, 8, 25, 23, 9, 44, tzinfo=datetime.timezone.utc),
#    'eight one six six heavy level three zero zero inbound gumpa'),
#   (datetime.datetime(2025, 8, 25, 23, 9, 49, tzinfo=datetime.timezone.utc),
#    'qatari eight one six six good day romeo five'),
#   (datetime.datetime(2025, 8, 25, 23, 9, 53, tzinfo=datetime.timezone.utc),
#    'praha good evening air france three nine six eight flight level three seven zero to navti'),
#   (datetime.datetime(2025, 8, 25, 23, 9, 58, tzinfo=datetime.timezone.utc),
#    'alpine three nine six eight good day ryan air five two six golf turn left'),
#   (datetime.datetime(2025, 8, 25, 23, 10, 3, tzinfo=datetime.timezone.utc),
#    'good afternoon klm five nine six'),
#   (datetime.datetime(2025, 8, 25, 23, 10, 30, tzinfo=datetime.timezone.utc),
#    'sun turk seven three eight two contact munich one two four decimal four three five good bye'),
#   (datetime.datetime(2025, 8, 25, 23, 10, 34, tzinfo=datetime.timezone.utc),
#    'one two four four three five turkish seven two eight'),
#   (datetime.datetime(2025, 8, 25, 23, 10, 42, tzinfo=datetime.timezone.utc),
#    'ok'),
#   (datetime.datetime(2025, 8, 25, 23, 10, 52, tzinfo=datetime.timezone.utc),
#    'channex five whiskey hotel good day identified proceed direct to sopel'),
#   (datetime.datetime(2025, 8, 25, 23, 10, 58, tzinfo=datetime.timezone.utc),
#    'direct to polchar next five whiskey hotel'),
#   (datetime.datetime(2025, 8, 25, 23, 11, 3, tzinfo=datetime.timezone.utc),
#    'passing level is one four zero zero climbing three six zero'),
#   (datetime.datetime(2025, 8, 25, 23, 11, 8, tzinfo=datetime.timezone.utc),
#    'swiss malta four four zero zero good day identified turn right heading zero eight zero and confirm level passing'),
#   (datetime.datetime(2025, 8, 25, 23, 11, 15, tzinfo=datetime.timezone.utc),
#    'right heading zero eight zero and passing two nine five with one tower four four zero zero'),
#   (datetime.datetime(2025, 8, 25, 23, 11, 20, tzinfo=datetime.timezone.utc),
#    'roger'),
#   (datetime.datetime(2025, 8, 25, 23, 13, 1, tzinfo=datetime.timezone.utc),
#    'air malta six three eight one six six request climb flight level three two zero'),
#   (datetime.datetime(2025, 8, 25, 23, 13, 6, tzinfo=datetime.timezone.utc),
#    'qatari eight one six six roger climb flight level three two zero'),
#   (datetime.datetime(2025, 8, 25, 23, 13, 9, tzinfo=datetime.timezone.utc),
#    'flight level three two zero qatari eight one six six'),
#   (datetime.datetime(2025, 8, 25, 23, 13, 13, tzinfo=datetime.timezone.utc),
#    'ryan air one one golf yankee contact lomman one one eight four eight zero good bye'),
#   (datetime.datetime(2025, 8, 25, 23, 13, 18, tzinfo=datetime.timezone.utc),
#    'hotel one one eight hotel romeo thank you bye'),
#   (datetime.datetime(2025, 8, 25, 23, 13, 21, tzinfo=datetime.timezone.utc),
#    'swiss one one eight four eight one eight four eight thanks ryan air one golf yankee way'),
#   (datetime.datetime(2025, 8, 25, 23, 16, 46, tzinfo=datetime.timezone.utc),
#    'easy seven nine zulu papa contact lomdon one two six decimal seven eight zero good bye'),
#   (datetime.datetime(2025, 8, 25, 23, 16, 51, tzinfo=datetime.timezone.utc),
#    'beline one two six seven eight zero seven nine two good bye'),
#   (datetime.datetime(2025, 8, 25, 23, 16, 56, tzinfo=datetime.timezone.utc),
#    'navigator good evening wizz air one seven two flight level three four zero to nogri'),
#   (datetime.datetime(2025, 8, 25, 23, 17, tzinfo=datetime.timezone.utc),
#    'swiss four one seven two good day ryan air five'),
#   (datetime.datetime(2025, 8, 25, 23, 18, 18, tzinfo=datetime.timezone.utc),
#    'radar ryan air one two lima xray flight level three six zero agro'),
#   (datetime.datetime(2025, 8, 25, 23, 18, 23, tzinfo=datetime.timezone.utc),
#    'ryan air one juliett mike say good day identified'),
#   (datetime.datetime(2025, 8, 25, 23, 19, 24, tzinfo=datetime.timezone.utc),
#    'swiss malta four four zero zero climb flight level three seven zero'),
#   (datetime.datetime(2025, 8, 25, 23, 19, 28, tzinfo=datetime.timezone.utc),
#    'beline three seven zero wind one seven four zero zero'),
#   (datetime.datetime(2025, 8, 25, 23, 21, 8, tzinfo=datetime.timezone.utc),
#    'bravo yankee romeo mike ruzyne one minimum frequency zero two one'),
#   (datetime.datetime(2025, 8, 25, 23, 21, 14, tzinfo=datetime.timezone.utc),
#    'to alfa with makal four four zero zero'),
#   (datetime.datetime(2025, 8, 25, 23, 21, 18, tzinfo=datetime.timezone.utc),
#    'and bozeman two two one zero good day identified proceed direct to lusko'),
#   (datetime.datetime(2025, 8, 25, 23, 21, 23, tzinfo=datetime.timezone.utc),
#    'rect to say again'),
#   (datetime.datetime(2025, 8, 25, 23, 21, 25, tzinfo=datetime.timezone.utc),
#    'direct to lufthansa lima uniform sierra oscar romeo direct to lufthansa portmanteau two one zero thank you'),
#   (datetime.datetime(2025, 8, 25, 23, 21, 33, tzinfo=datetime.timezone.utc),
#    'alpine three nine six eight contact munchen one three two decimal seven five five good bye'),
#   (datetime.datetime(2025, 8, 25, 23, 21, 38, tzinfo=datetime.timezone.utc),
#    'one three two decimal seven five five lot five three nine six'),
#   (datetime.datetime(2025, 8, 25, 23, 22, 15, tzinfo=datetime.timezone.utc),
#    'ryan air six four juliett alfa contact lomman one two eight decimal one six zero good bye'),
#   (datetime.datetime(2025, 8, 25, 23, 22, 21, tzinfo=datetime.timezone.utc),
#    'one two eight one six zero ryan air six four juliett delta'),
#   (datetime.datetime(2025, 8, 25, 23, 25, 7, tzinfo=datetime.timezone.utc),
#    'qatari eight one six six contact romeo again one three four decimal six eight zero good bye'),
#   (datetime.datetime(2025, 8, 25, 23, 25, 13, tzinfo=datetime.timezone.utc),
#    'one three four six eight zero qatari eight one six six good day'),
#   (datetime.datetime(2025, 8, 25, 23, 25, 18, tzinfo=datetime.timezone.utc),
#    'ryan air six four november yankee contact romeo one two six seven eight zero good bye'),
#   (datetime.datetime(2025, 8, 25, 23, 25, 23, tzinfo=datetime.timezone.utc),
#    'four six seven eight ryan air six four november yankee bye'),
#   (datetime.datetime(2025, 8, 25, 23, 26, 43, tzinfo=datetime.timezone.utc),
#    'proceed good evening wizz air five nine quebec whiskey climbing flight level two seven zero approaching zephyr'),
#   (datetime.datetime(2025, 8, 25, 23, 26, 49, tzinfo=datetime.timezone.utc),
#    'swiss one two nine expect whiskey good day identified confirm requested flight level'),
#   (datetime.datetime(2025, 8, 25, 23, 26, 54, tzinfo=datetime.timezone.utc),
#    'three seven zero final squawk'),
#   (datetime.datetime(2025, 8, 25, 23, 26, 56, tzinfo=datetime.timezone.utc),
#    'ok'),
#   (datetime.datetime(2025, 8, 25, 23, 27, 37, tzinfo=datetime.timezone.utc),
#    'channex five six two contact lonni one two six decimal seven eight zero good bye'),
#   (datetime.datetime(2025, 8, 25, 23, 27, 43, tzinfo=datetime.timezone.utc),
#    'legend one three six decimal seven eight zero good bye qnh five whiskey hotel'),
#   (datetime.datetime(2025, 8, 25, 23, 28, 36, tzinfo=datetime.timezone.utc),
#    'three five'),
#   (datetime.datetime(2025, 8, 25, 23, 29, 7, tzinfo=datetime.timezone.utc),
#    'asterix ryan air one one three four climb four one zero direct tatra'),
#   (datetime.datetime(2025, 8, 25, 23, 29, 12, tzinfo=datetime.timezone.utc),
#    'ryan air one one three four good day romeo five three eight'),
#   (datetime.datetime(2025, 8, 25, 23, 29, 30, tzinfo=datetime.timezone.utc),
#    'swiss mal seven nine quebec whiskey proceed direct to omelo'),
#   (datetime.datetime(2025, 8, 25, 23, 29, 33, tzinfo=datetime.timezone.utc),
#    'affirm el al five two eight please'),
#   (datetime.datetime(2025, 8, 25, 23, 29, 41, tzinfo=datetime.timezone.utc),
#    'swiss malta four four zero zero contact munchen one two four four three five good bye'),
#   (datetime.datetime(2025, 8, 25, 23, 29, 46, tzinfo=datetime.timezone.utc),
#    'one three four four three five wizz air four four two zero good bye'),
#   (datetime.datetime(2025, 8, 25, 23, 29, 51, tzinfo=datetime.timezone.utc),
#    'and make it if it is one two four four three five'),
#   (datetime.datetime(2025, 8, 25, 23, 29, 54, tzinfo=datetime.timezone.utc),
#    'one two four four three five swiss one two four four zero'),
#   (datetime.datetime(2025, 8, 25, 23, 31, 13, tzinfo=datetime.timezone.utc),
#    'swiss four one seven two contact lufthansa one two eight decimal one six zero good bye'),
#   (datetime.datetime(2025, 8, 25, 23, 31, 18, tzinfo=datetime.timezone.utc),
#    'one two eight decimal one six zero wizz air one one seven two'),
#   (datetime.datetime(2025, 8, 25, 23, 32, 33, tzinfo=datetime.timezone.utc),
#    'ryan air one juliett mike say contact lomki on one two eight decimal one six zero good bye'),
#   (datetime.datetime(2025, 8, 25, 23, 32, 38, tzinfo=datetime.timezone.utc),
#    'one two eight one six zero ryan air one two lima xray go ahead'),
#   (datetime.datetime(2025, 8, 25, 23, 33, 58, tzinfo=datetime.timezone.utc),
#    'good morning china twenty two flight level three six zero direct to go to emirates'),
#   (datetime.datetime(2025, 8, 25, 23, 34, 6, tzinfo=datetime.timezone.utc),
#    'channex one eight two good day ryan air five two two golf'),
#   (datetime.datetime(2025, 8, 25, 23, 34, 12, tzinfo=datetime.timezone.utc),
#    'direct to romeo charlie zulu'),
#   (datetime.datetime(2025, 8, 25, 23, 34, 35, tzinfo=datetime.timezone.utc),
#    'three five'),
#   (datetime.datetime(2025, 8, 25, 23, 34, 58, tzinfo=datetime.timezone.utc),
#    'three five'),
#   (datetime.datetime(2025, 8, 25, 23, 36, 9, tzinfo=datetime.timezone.utc),
#    'five six'),
#   (datetime.datetime(2025, 8, 25, 23, 37, 46, tzinfo=datetime.timezone.utc),
#    'brosman two two one zero contact romeo one two eight decimal one six zero good bye'),
#   (datetime.datetime(2025, 8, 25, 23, 37, 52, tzinfo=datetime.timezone.utc),
#    'one two eight one six zero borsch one two two one good bye'),
#   (datetime.datetime(2025, 8, 25, 23, 38, 12, tzinfo=datetime.timezone.utc),
#    'morning passi channex two romeo charlie we are flight level three six zero'),
#   (datetime.datetime(2025, 8, 25, 23, 38, 17, tzinfo=datetime.timezone.utc),
#    'channex two romeo charlie good day hotel charlie'),
#   (datetime.datetime(2025, 8, 25, 23, 38, 23, tzinfo=datetime.timezone.utc),
#    'five five'),
#   (datetime.datetime(2025, 8, 25, 23, 38, 33, tzinfo=datetime.timezone.utc),
#    'bratislava good evening channex five zero eight flight level three six zero direct bratislava channex five zero eight good day hotel alfa'),
#   (datetime.datetime(2025, 8, 25, 23, 41, 7, tzinfo=datetime.timezone.utc),
#    'navbridge control hello turkish two alfa mike maintaining flight level three five zero turkish two alfa mike can you identified confirm you are on course to omelo'),
#   (datetime.datetime(2025, 8, 25, 23, 41, 18, tzinfo=datetime.timezone.utc),
#    'affirm proceeding omelo turkish two alfa mike'),
#   (datetime.datetime(2025, 8, 25, 23, 41, 21, tzinfo=datetime.timezone.utc),
#    'turkish two alfa mike that is copied we do have a different plan in our system we have to double check with the flight data we have a flight plan via ifr now'),
#   (datetime.datetime(2025, 8, 25, 23, 43, 10, tzinfo=datetime.timezone.utc),
#    'turkish two alfa mike'),
#   (datetime.datetime(2025, 8, 25, 23, 43, 13, tzinfo=datetime.timezone.utc),
#    'we are checking out right now turkish two alfa mike'),
#   (datetime.datetime(2025, 8, 25, 23, 43, 17, tzinfo=datetime.timezone.utc),
#    'turkish two alfa mike yeah we also checked with our flight data seems like we still have an old flight plan we have the most recent one i will send you a point via ctr and you can expect further route from atr'),
#   (datetime.datetime(2025, 8, 25, 23, 43, 31, tzinfo=datetime.timezone.utc),
#    'we found our new our flight plan and we are correcting our route you can give us any direct on the new flight plan turkish two alfa mike'),
#   (datetime.datetime(2025, 8, 25, 23, 43, 41, tzinfo=datetime.timezone.utc),
#    'roger it is coming up on tbk csa'),
#   (datetime.datetime(2025, 8, 25, 23, 43, 46, tzinfo=datetime.timezone.utc),
#    'roger charlie alfa mike'),
#   (datetime.datetime(2025, 8, 25, 23, 44, 6, tzinfo=datetime.timezone.utc),
#    'swiss malta nine xray whiskey contact munich one three zero decimal one one zero good bye'),
#   (datetime.datetime(2025, 8, 25, 23, 44, 12, tzinfo=datetime.timezone.utc),
#    'one two zero one one zero lufthansa two echo xray bye bye'),
#   (datetime.datetime(2025, 8, 25, 23, 44, 17, tzinfo=datetime.timezone.utc),
#    'navigator hello channex seven golf yankee flight level three eight zero direct rapet'),
#   (datetime.datetime(2025, 8, 25, 23, 44, 22, tzinfo=datetime.timezone.utc),
#    'yanair seven golf yankee good evening and at five track six two thousand'),
#   (datetime.datetime(2025, 8, 25, 23, 44, 26, tzinfo=datetime.timezone.utc),
#    'sky travel seven zero five yankee thank you'),
#   (datetime.datetime(2025, 8, 25, 23, 45, 41, tzinfo=datetime.timezone.utc),
#    'departure channex five seven juliett whiskey flight level three six zero montana'),
#   (datetime.datetime(2025, 8, 25, 23, 45, 47, tzinfo=datetime.timezone.utc),
#    'channex five seven juliett whiskey clear land five three six vector voz'),
#   (datetime.datetime(2025, 8, 25, 23, 45, 52, tzinfo=datetime.timezone.utc),
#    'hotel bravo yankee nine five seven zero whiskey'),
#   (datetime.datetime(2025, 8, 25, 23, 48, 29, tzinfo=datetime.timezone.utc),
#    'channex one eight two contact lomman one two six decimal seven eight zero good bye'),
#   (datetime.datetime(2025, 8, 25, 23, 48, 34, tzinfo=datetime.timezone.utc),
#    'one two six seven eight zero time air five two five'),
#   (datetime.datetime(2025, 8, 25, 23, 48, 49, tzinfo=datetime.timezone.utc),
#    'three five'),
#   (datetime.datetime(2025, 8, 25, 23, 49, 34, tzinfo=datetime.timezone.utc),
#    'praha six good evening mosquito seven delta bravo flight level three two zero direct november'),
#   (datetime.datetime(2025, 8, 25, 23, 49, 39, tzinfo=datetime.timezone.utc),
#    'swiss two seven delta bravo good day identified'),
#   (datetime.datetime(2025, 8, 25, 23, 52, 26, tzinfo=datetime.timezone.utc),
#    'contact three xray hotel good day identified continue present heading are you looking for higher'),
#   (datetime.datetime(2025, 8, 25, 23, 52, 31, tzinfo=datetime.timezone.utc),
#    'negative we can climb we can climb flight level three five zero'),
#   (datetime.datetime(2025, 8, 25, 23, 52, 35, tzinfo=datetime.timezone.utc),
#    'roger'),
#   (datetime.datetime(2025, 8, 25, 23, 52, 36, tzinfo=datetime.timezone.utc),
#    'praha heading confirm sun turk three eight zero seven ok'),
#   (datetime.datetime(2025, 8, 25, 23, 53, 11, tzinfo=datetime.timezone.utc),
#    'swiss four nine one zero nine good day hotel alfa'),
#   (datetime.datetime(2025, 8, 25, 23, 53, 18, tzinfo=datetime.timezone.utc),
#    'channex two romeo charlie contact squawk one two one decimal three two five good bye'),
#   (datetime.datetime(2025, 8, 25, 23, 56, 51, tzinfo=datetime.timezone.utc),
#    'say say is that four two six seven eight zero china xray golf yankee'),
#   (datetime.datetime(2025, 8, 25, 23, 56, 58, tzinfo=datetime.timezone.utc),
#    'thank you one two six decimal seven eight zero two seven golf yankee bye bye'),
#   (datetime.datetime(2025, 8, 25, 23, 57, 52, tzinfo=datetime.timezone.utc),
#    'channex five zero eight contact scotch one two one three two five good bye'),
#   (datetime.datetime(2025, 8, 25, 23, 57, 57, tzinfo=datetime.timezone.utc),
#    'one two one three two five good morning channex five zero eight'),
#   (datetime.datetime(2025, 8, 25, 23, 59, 42, tzinfo=datetime.timezone.utc),
#    'channex five seven juliett whiskey contact lomman one two six seven eight zero good bye'),
#   (datetime.datetime(2025, 8, 25, 23, 59, 48, tzinfo=datetime.timezone.utc),
#    'lot three six seven eight zero china five seven zero whiskey good day')],
#  []]
